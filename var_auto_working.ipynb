# %%
import numpy as np
from tensorflow import keras
from keras.layers import Input, Dense, Lambda
import tensorflow as tf
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from keras import backend as K
from sklearn.model_selection import train_test_split

# %%
# Define the desired number of samples for each class
class_samples = [2000, 3000, 2500, 1500]  # Adjust these numbers as needed

# Calculate weights based on the desired number of samples
class_weights = [num_samples / sum(class_samples) for num_samples in class_samples]


# Generate a synthetic dataset with different numbers of samples for each class
X, y = make_classification(
    n_samples=sum(class_samples),
    n_features=4,
    n_informative=4,
    n_redundant=0,
    n_classes=4,
    weights=class_weights,
    random_state=42,
)


# Create a Pandas DataFrame with the generated data
columns = ["Feature_1", "Feature_2", "Feature_3", "Feature_4"]
synthetic_df = pd.DataFrame(data=X, columns=columns)

for column in synthetic_df:
    std = np.std(synthetic_df[column])
    mean = np.mean(synthetic_df[column])
    synthetic_df[column] = synthetic_df[column]-mean
    synthetic_df[column] = synthetic_df[column]/std


synthetic_df["target"] = y

# Display the first few rows of the synthetic dataset
synthetic_array =synthetic_df.values

# %%
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 10
encoder_inputs = Input(shape=(5), name="input_layer")
x1 = Dense(50, activation="relu", name="h1")(encoder_inputs)
x2 = Dense(40, activation="relu", name="h2")(x1)

n_x3 = 30

x3 = Dense(n_x3, activation="relu", name="h3")(x2)

# Split x3 into two halves
half_size = n_x3 // 2
x3_first_half = Lambda(lambda x: x[:, :half_size], name="select_z_mean")(x3)
x3_second_half = Lambda(lambda x: x[:, half_size:], name="select_z_var")(x3)

z_mean = Dense(latent_dim, name="z_mean")(x3_first_half)
z_log_var = Dense(latent_dim, name="z_log_var")(x3_second_half)
z = Sampling(name="Sampling")([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# %%
keras.utils.plot_model(encoder, show_shapes=True)

# %%
n_x6 = 50
int(n_x6 * 0.8 - 1)
# Out:
# 39

# %%
# Decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x4 = Dense(30, activation="relu", name="h4")(latent_inputs)
x5 = Dense(40, activation="relu", name="h5")(x4)

n_x6 = 50

x6 = Dense(n_x6, activation="relu", name="h6")(x5)

# Split x6 into two parts (80% and 20%)
cont_decoder_input = Lambda(lambda x: x[:, :int(0.8 * n_x6)], name="select_x6_cont")(x6)
class_decoder_input = Lambda(lambda x: x[:, int(0.8 * n_x6):], name="select_x6_class")(x6)

cont_decoder_outputs = Dense(4, name="cont_decoder_output")(cont_decoder_input)
class_decoder_output = Dense(4, activation="softmax", name="classification_output")(class_decoder_input)

decoder = keras.Model(latent_inputs, [cont_decoder_outputs, class_decoder_output], name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  h4 (Dense)                     (None, 30)           330         ['input_2[0][0]']
#
#  h5 (Dense)                     (None, 40)           1240        ['h4[0][0]']
#
#  h6 (Dense)                     (None, 50)           2050        ['h5[0][0]']
#
#  select_x6_cont (Lambda)        (None, 40)           0           ['h6[0][0]']
#
#  select_x6_class (Lambda)       (None, 10)           0           ['h6[0][0]']
#  cont_decoder_output (Dense)    (None, 4)            164         ['select_x6_cont[0][0]']
#
#  classification_output (Dense)  (None, 4)            44          ['select_x6_class[0][0]']
#
# ==================================================================================================
# Total params: 3,828
# Trainable params: 3,828
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.reconstruction_loss_class_tracker = keras.metrics.Mean(
            name="reconstruction_loss_class"
        )

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.reconstruction_loss_class_tracker,
            keras.metrics.SparseCategoricalCrossentropy(
                name="sparse_categorical_crossentropy"
            ),
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction_cont, reconstruction_class = self.decoder(z)

            data_cont = data[
                :, :4
            ]  # Assuming the first 4 columns are for continuous variables
            data_class = data[:, 4:]  # Assuming the last column is for classification

            # Reconstruction loss for continuous outputs
            reconstruction_loss_cont = keras.losses.mean_squared_error(
                data_cont, reconstruction_cont
            )

            # Reconstruction loss for classification output
            reconstruction_loss_class = keras.losses.sparse_categorical_crossentropy(
                data_class, reconstruction_class
            )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(kl_loss, axis=1)

            # Combine losses
            total_loss = (
                0.8*reconstruction_loss_cont + 0.2*reconstruction_loss_class + kl_loss
            )

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
            "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "sparse_categorical_crossentropy": self.reconstruction_loss_class_tracker.result(), 
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())

# %%
# Specify the test_size and validation_size according to your needs
test_size = 0.2  # 80% training, 20% test
validation_size = 0.1  # 80% training, 10% validation

# Split into training and temporary data
train_data, temp_data = train_test_split(
    synthetic_array, test_size=test_size + validation_size, random_state=42
)

# Split the temporary data into test and validation
test_data, validation_data = train_test_split(
    temp_data,
    test_size=validation_size / (test_size + validation_size),
    random_state=42,
)


# # Convert NumPy arrays to tf.data.Dataset
# train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
# validation_dataset = tf.data.Dataset.from_tensor_slices(
#     (validation_data, validation_data)
# )
# test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_data))

# %%
from keras.callbacks import EarlyStopping

vae.fit(
    synthetic_array,
    epochs=70,
    batch_size=16,
    callbacks=[EarlyStopping(monitor="loss", patience=5, restore_best_weights=True)],
)
# Out:
# Epoch 1/70
# 563/563 [==============================] - 4s 5ms/step - loss: 1.0458 - reconstruction_loss_cont: 0.9167 - reconstruction_loss_class: 1.3199 - kl_loss: 0.0908 - sparse_categorical_crossentropy: 1.3199
# Epoch 2/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.8003 - reconstruction_loss_cont: 0.4248 - reconstruction_loss_class: 1.0880 - kl_loss: 0.2497 - sparse_categorical_crossentropy: 1.0880
# Epoch 3/70
# 563/563 [==============================] - 3s 4ms/step - loss: 0.7152 - reconstruction_loss_cont: 0.3050 - reconstruction_loss_class: 0.9599 - kl_loss: 0.2783 - sparse_categorical_crossentropy: 0.9599
# Epoch 4/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.6751 - reconstruction_loss_cont: 0.2640 - reconstruction_loss_class: 0.8334 - kl_loss: 0.2958 - sparse_categorical_crossentropy: 0.8334
# Epoch 5/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.6485 - reconstruction_loss_cont: 0.2478 - reconstruction_loss_class: 0.7022 - kl_loss: 0.3096 - sparse_categorical_crossentropy: 0.7022
# Epoch 6/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.6346 - reconstruction_loss_cont: 0.2440 - reconstruction_loss_class: 0.6125 - kl_loss: 0.3179 - sparse_categorical_crossentropy: 0.6125
# Epoch 7/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.6199 - reconstruction_loss_cont: 0.2346 - reconstruction_loss_class: 0.5224 - kl_loss: 0.3264 - sparse_categorical_crossentropy: 0.5224
# Epoch 8/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.6078 - reconstruction_loss_cont: 0.2293 - reconstruction_loss_class: 0.4447 - kl_loss: 0.3333 - sparse_categorical_crossentropy: 0.4447
# Epoch 9/70
# 563/563 [==============================] - 3s 4ms/step - loss: 0.6022 - reconstruction_loss_cont: 0.2294 - reconstruction_loss_class: 0.3908 - kl_loss: 0.3400 - sparse_categorical_crossentropy: 0.3908
# Epoch 10/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.5927 - reconstruction_loss_cont: 0.2264 - reconstruction_loss_class: 0.3397 - kl_loss: 0.3436 - sparse_categorical_crossentropy: 0.3397
# Epoch 11/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.5868 - reconstruction_loss_cont: 0.2251 - reconstruction_loss_class: 0.2970 - kl_loss: 0.3483 - sparse_categorical_crossentropy: 0.2970
# Epoch 12/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.5805 - reconstruction_loss_cont: 0.2223 - reconstruction_loss_class: 0.2683 - kl_loss: 0.3497 - sparse_categorical_crossentropy: 0.2683
# Epoch 13/70
# 563/563 [==============================] - 2s 4ms/step - loss: 0.5772 - reconstruction_loss_cont: 0.2166 - reconstruction_loss_class: 0.2598 - kl_loss: 0.3518 - sparse_categorical_crossentropy: 0.2598
# Epoch 14/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5814 - reconstruction_loss_cont: 0.2232 - reconstruction_loss_class: 0.2538 - kl_loss: 0.3538 - sparse_categorical_crossentropy: 0.2538
# Epoch 15/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5762 - reconstruction_loss_cont: 0.2197 - reconstruction_loss_class: 0.2345 - kl_loss: 0.3531 - sparse_categorical_crossentropy: 0.2345
# Epoch 16/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5683 - reconstruction_loss_cont: 0.2177 - reconstruction_loss_class: 0.2212 - kl_loss: 0.3528 - sparse_categorical_crossentropy: 0.2212
# Epoch 17/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5751 - reconstruction_loss_cont: 0.2172 - reconstruction_loss_class: 0.2107 - kl_loss: 0.3564 - sparse_categorical_crossentropy: 0.2107
# Epoch 18/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5720 - reconstruction_loss_cont: 0.2178 - reconstruction_loss_class: 0.2019 - kl_loss: 0.3558 - sparse_categorical_crossentropy: 0.2019
# Epoch 19/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5657 - reconstruction_loss_cont: 0.2144 - reconstruction_loss_class: 0.1907 - kl_loss: 0.3564 - sparse_categorical_crossentropy: 0.1907
# Epoch 20/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5666 - reconstruction_loss_cont: 0.2149 - reconstruction_loss_class: 0.1938 - kl_loss: 0.3572 - sparse_categorical_crossentropy: 0.1938
# Epoch 21/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5691 - reconstruction_loss_cont: 0.2177 - reconstruction_loss_class: 0.1960 - kl_loss: 0.3547 - sparse_categorical_crossentropy: 0.1960
# Epoch 22/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5690 - reconstruction_loss_cont: 0.2179 - reconstruction_loss_class: 0.1865 - kl_loss: 0.3554 - sparse_categorical_crossentropy: 0.1865
# Epoch 23/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5651 - reconstruction_loss_cont: 0.2141 - reconstruction_loss_class: 0.1892 - kl_loss: 0.3579 - sparse_categorical_crossentropy: 0.1892
# Epoch 24/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5675 - reconstruction_loss_cont: 0.2132 - reconstruction_loss_class: 0.1790 - kl_loss: 0.3569 - sparse_categorical_crossentropy: 0.1790
# Epoch 25/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5665 - reconstruction_loss_cont: 0.2093 - reconstruction_loss_class: 0.1776 - kl_loss: 0.3614 - sparse_categorical_crossentropy: 0.1776
# Epoch 26/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5607 - reconstruction_loss_cont: 0.2107 - reconstruction_loss_class: 0.1804 - kl_loss: 0.3548 - sparse_categorical_crossentropy: 0.1804
# Epoch 27/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5617 - reconstruction_loss_cont: 0.2105 - reconstruction_loss_class: 0.1728 - kl_loss: 0.3610 - sparse_categorical_crossentropy: 0.1728
# Epoch 28/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5613 - reconstruction_loss_cont: 0.2119 - reconstruction_loss_class: 0.1790 - kl_loss: 0.3588 - sparse_categorical_crossentropy: 0.1790
# Epoch 29/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5627 - reconstruction_loss_cont: 0.2119 - reconstruction_loss_class: 0.1691 - kl_loss: 0.3596 - sparse_categorical_crossentropy: 0.1691
# Epoch 30/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5626 - reconstruction_loss_cont: 0.2113 - reconstruction_loss_class: 0.1710 - kl_loss: 0.3590 - sparse_categorical_crossentropy: 0.1710
# Epoch 31/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5569 - reconstruction_loss_cont: 0.2127 - reconstruction_loss_class: 0.1723 - kl_loss: 0.3563 - sparse_categorical_crossentropy: 0.1723
# Epoch 32/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5605 - reconstruction_loss_cont: 0.2096 - reconstruction_loss_class: 0.1670 - kl_loss: 0.3584 - sparse_categorical_crossentropy: 0.1670
# Epoch 33/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5595 - reconstruction_loss_cont: 0.2134 - reconstruction_loss_class: 0.1650 - kl_loss: 0.3571 - sparse_categorical_crossentropy: 0.1650
# Epoch 34/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5621 - reconstruction_loss_cont: 0.2092 - reconstruction_loss_class: 0.1630 - kl_loss: 0.3619 - sparse_categorical_crossentropy: 0.1630
# Epoch 35/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5590 - reconstruction_loss_cont: 0.2082 - reconstruction_loss_class: 0.1658 - kl_loss: 0.3563 - sparse_categorical_crossentropy: 0.1658
# Epoch 36/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5591 - reconstruction_loss_cont: 0.2093 - reconstruction_loss_class: 0.1672 - kl_loss: 0.3577 - sparse_categorical_crossentropy: 0.1672
# Epoch 37/70
# 563/563 [==============================] - 3s 6ms/step - loss: 0.5604 - reconstruction_loss_cont: 0.2115 - reconstruction_loss_class: 0.1582 - kl_loss: 0.3606 - sparse_categorical_crossentropy: 0.1582
# Epoch 38/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5565 - reconstruction_loss_cont: 0.2107 - reconstruction_loss_class: 0.1612 - kl_loss: 0.3579 - sparse_categorical_crossentropy: 0.1612
# Epoch 39/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5602 - reconstruction_loss_cont: 0.2079 - reconstruction_loss_class: 0.1514 - kl_loss: 0.3611 - sparse_categorical_crossentropy: 0.1514
# Epoch 40/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5540 - reconstruction_loss_cont: 0.2065 - reconstruction_loss_class: 0.1615 - kl_loss: 0.3577 - sparse_categorical_crossentropy: 0.1615
# Epoch 41/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5606 - reconstruction_loss_cont: 0.2089 - reconstruction_loss_class: 0.1600 - kl_loss: 0.3624 - sparse_categorical_crossentropy: 0.1600
# Epoch 42/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5572 - reconstruction_loss_cont: 0.2099 - reconstruction_loss_class: 0.1601 - kl_loss: 0.3566 - sparse_categorical_crossentropy: 0.1601
# Epoch 43/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5549 - reconstruction_loss_cont: 0.2094 - reconstruction_loss_class: 0.1568 - kl_loss: 0.3591 - sparse_categorical_crossentropy: 0.1568
# Epoch 44/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5577 - reconstruction_loss_cont: 0.2083 - reconstruction_loss_class: 0.1582 - kl_loss: 0.3559 - sparse_categorical_crossentropy: 0.1582
# Epoch 45/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5535 - reconstruction_loss_cont: 0.2096 - reconstruction_loss_class: 0.1460 - kl_loss: 0.3583 - sparse_categorical_crossentropy: 0.1460
# Epoch 46/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5515 - reconstruction_loss_cont: 0.2082 - reconstruction_loss_class: 0.1554 - kl_loss: 0.3582 - sparse_categorical_crossentropy: 0.1554
# Epoch 47/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5584 - reconstruction_loss_cont: 0.2097 - reconstruction_loss_class: 0.1515 - kl_loss: 0.3590 - sparse_categorical_crossentropy: 0.1515
# Epoch 48/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5581 - reconstruction_loss_cont: 0.2089 - reconstruction_loss_class: 0.1503 - kl_loss: 0.3606 - sparse_categorical_crossentropy: 0.1503
# Epoch 49/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5534 - reconstruction_loss_cont: 0.2095 - reconstruction_loss_class: 0.1497 - kl_loss: 0.3592 - sparse_categorical_crossentropy: 0.1497
# Epoch 50/70
# 563/563 [==============================] - 3s 5ms/step - loss: 0.5564 - reconstruction_loss_cont: 0.2087 - reconstruction_loss_class: 0.1475 - kl_loss: 0.3594 - sparse_categorical_crossentropy: 0.1475

# %%
latent_vectors = np.random.normal(size=(9000, latent_dim))

# Use the decoder to generate data
generated_data_cont, generated_data_class = vae.decoder.predict(latent_vectors)
# Out:
# 282/282 [==============================] - 0s 1ms/step

# %%
generated_data_class_transformed = np.argmax(generated_data_class, axis=1)

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = synthetic_array[:, 4]

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = generated_data_class_transformed

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = synthetic_array[:, 1]

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = generated_data_cont[:, 1]

# Plot histogram
plt.hist(first_column, bins=25, color="g", alpha=0.6)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
synthetic_array[:, 1]
# Out:
# array([ 1.92185791, -1.1803525 , -0.65872548, ..., -0.76488573,
#         0.8426321 ,  1.43199527])

# %%
generated_data_cont[:, 1]
# Out:
# array([ 1.166388  , -0.9083656 ,  1.0234121 , ...,  0.61383605,
#        -0.07954051,  0.3516659 ], dtype=float32)

# %%
from scipy.stats import entropy



entropy(
    synthetic_array[:, 1], qk=generated_data_cont[:, 1], base=2
)  # base=2 for logarithm base 2
# Out:
# inf

# %%
def kl_divergence_histogram(p, q, bins=10):
    hist_p, bin_edges = np.histogram(p, bins=bins, density=True)
    hist_q, _ = np.histogram(q, bins=bin_edges, density=True)

    #kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))

    return  hist_p, hist_q

# %%
def kl_divergence_histogram(p, q, bins=10):
    hist_p, bin_edges = np.histogram(p, bins=bins, density=True)
    hist_q, _ = np.histogram(q, bins=bin_edges, density=True)

    kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))

    return kl_div, hist_p, hist_q


# Example usage
array_p = np.array([1.166388, -0.9083656, 1.0234121])
array_q = np.array([0.61383605, -0.07954051, 0.3516659])

result = kl_divergence_histogram(array_p, array_q, bins=10)
print(f"KL Divergence: {result}")
# Out:
# KL Divergence: nan
# C:\Users\Max_G\AppData\Local\Temp\ipykernel_24376\2172624307.py:5: RuntimeWarning: divide by zero encountered in log
#   kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))
# C:\Users\Max_G\AppData\Local\Temp\ipykernel_24376\2172624307.py:5: RuntimeWarning: invalid value encountered in multiply
#   kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))
