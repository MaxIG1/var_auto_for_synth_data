# %%
import numpy as np
from tensorflow import keras
from keras.layers import Input, Dense, Lambda
import tensorflow as tf
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from keras import backend as K
from sklearn.model_selection import train_test_split

# %%
# Check for GPU availability
if tf.config.list_physical_devices("GPU"):
    print("GPU is available.")
    physical_devices = tf.config.list_physical_devices("GPU")
    tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
else:
    print("GPU is not available. Switching to CPU.")
# Out:
# GPU is not available. Switching to CPU.

# %%
# Define the desired number of samples for each class
class_samples = [20000, 30000, 25000, 15000]  # Adjust these numbers as needed

# Calculate weights based on the desired number of samples
class_weights = [num_samples / sum(class_samples) for num_samples in class_samples]


# Generate a synthetic dataset with different numbers of samples for each class
X, y = make_classification(
    n_samples=sum(class_samples),
    n_features=4,
    n_informative=4,
    n_redundant=0,
    n_classes=4,
    weights=class_weights,
    random_state=42,
)


# Create a Pandas DataFrame with the generated data
columns = ["Feature_1", "Feature_2", "Feature_3", "Feature_4"]
synthetic_df = pd.DataFrame(data=X, columns=columns)

for column in synthetic_df:
    std = np.std(synthetic_df[column])
    mean = np.mean(synthetic_df[column])
    synthetic_df[column] = synthetic_df[column]-mean
    synthetic_df[column] = synthetic_df[column]/std


synthetic_df["target"] = y

# Display the first few rows of the synthetic dataset
synthetic_array =synthetic_df.values

# %%
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 10
encoder_inputs = Input(shape=(5), name="input_layer")
x1 = Dense(50, activation="relu", name="h1")(encoder_inputs)
x2 = Dense(40, activation="relu", name="h2")(x1)

n_x3 = 30

x3 = Dense(n_x3, activation="relu", name="h3")(x2)

# Split x3 into two halves
half_size = n_x3 // 2
x3_first_half = Lambda(lambda x: x[:, :half_size], name="select_z_mean")(x3)
x3_second_half = Lambda(lambda x: x[:, half_size:], name="select_z_var")(x3)

z_mean = Dense(latent_dim, name="z_mean")(x3_first_half)
z_log_var = Dense(latent_dim, name="z_log_var")(x3_second_half)
z = Sampling(name="Sampling")([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# %%
keras.utils.plot_model(encoder, show_shapes=True)

# %%
n_x6 = 50
int(n_x6 * 0.8 - 1)
# Out:
# 39

# %%
# Decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x4 = Dense(30, activation="relu", name="h4")(latent_inputs)
x5 = Dense(40, activation="relu", name="h5")(x4)

n_x6 = 50

x6 = Dense(n_x6, activation="relu", name="h6")(x5)

# Split x6 into two parts (80% and 20%)
cont_decoder_input = Lambda(lambda x: x[:, :int(0.8 * n_x6)], name="select_x6_cont")(x6)
class_decoder_input = Lambda(lambda x: x[:, int(0.8 * n_x6):], name="select_x6_class")(x6)

cont_decoder_outputs = Dense(4, name="cont_decoder_output")(cont_decoder_input)
class_decoder_output = Dense(4, activation="softmax", name="classification_output")(class_decoder_input)

decoder = keras.Model(latent_inputs, [cont_decoder_outputs, class_decoder_output], name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 10)]         0           []
#
#  h4 (Dense)                     (None, 30)           330         ['input_8[0][0]']
#
#  h5 (Dense)                     (None, 40)           1240        ['h4[0][0]']
#
#  h6 (Dense)                     (None, 50)           2050        ['h5[0][0]']
#
#  select_x6_cont (Lambda)        (None, 40)           0           ['h6[0][0]']
#
#  select_x6_class (Lambda)       (None, 10)           0           ['h6[0][0]']
#
#  cont_decoder_output (Dense)    (None, 4)            164         ['select_x6_cont[0][0]']
#
#  classification_output (Dense)  (None, 4)            44          ['select_x6_class[0][0]']
#
# ==================================================================================================
# Total params: 3,828
# Trainable params: 3,828
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.reconstruction_loss_class_tracker = keras.metrics.Mean(
            name="reconstruction_loss_class"
        )

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.reconstruction_loss_class_tracker,
            keras.metrics.SparseCategoricalCrossentropy(
                name="sparse_categorical_crossentropy"
            ),
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction_cont, reconstruction_class = self.decoder(z)

            data_cont = data[
                :, :4
            ]  # Assuming the first 4 columns are for continuous variables
            data_class = data[:, 4:]  # Assuming the last column is for classification

            # Reconstruction loss for continuous outputs
            reconstruction_loss_cont = keras.losses.mean_squared_error(
                data_cont, reconstruction_cont
            )

            # Reconstruction loss for classification output
            reconstruction_loss_class = keras.losses.sparse_categorical_crossentropy(
                data_class, reconstruction_class
            )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(kl_loss, axis=1)

            # Combine losses
            total_loss = (
                0.8*reconstruction_loss_cont + 0.2*reconstruction_loss_class + kl_loss
            )

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
            "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "sparse_categorical_crossentropy": self.reconstruction_loss_class_tracker.result(), 
        }
    


    def test_step(self, data):
        """Step run during validation."""
        if isinstance(data, tuple):
            data = data[0]  # Unpack the tuple and take the input data

        data_cont = data[:, :4]  # Assuming the first 4 columns are for continuous variables
        data_class = data[:, 4:]  # Assuming the last column is for classification

        z_mean, z_log_var, reconstruction = self.encoder(data)
        reconstruction_loss_cont = keras.losses.mean_squared_error(
                data_cont, reconstruction[:, :4])

        # Reconstruction loss for classification output
        reconstruction_loss_class = keras.losses.sparse_categorical_crossentropy(
                data_class,  reconstruction[:, 4:]
            )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(kl_loss, axis=1)

        # Combine losses
        total_loss = (
                0.8*reconstruction_loss_cont + 0.2*reconstruction_loss_class + kl_loss
            )

        return {
            "loss": total_loss,
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())

# %%
# Specify the test_size and validation_size according to your needs
test_size = 0.2  # 80% training, 20% test
validation_size = 0.1  # 80% training, 10% validation

# Split into training and temporary data
train_data, temp_data = train_test_split(
    synthetic_array, test_size=test_size + validation_size, random_state=42
)

# Split the temporary data into test and validation
test_data, validation_data = train_test_split(
    temp_data,
    test_size=validation_size / (test_size + validation_size),
    random_state=42,
)


# # Convert NumPy arrays to tf.data.Dataset
# train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
# validation_dataset = tf.data.Dataset.from_tensor_slices(
#     (validation_data, validation_data)
# )
# test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_data))

# %%
from keras.callbacks import EarlyStopping
# early_stopping_callback = EarlyStopping(
#     monitor='val_loss',  # Monitoring validation loss
#     patience=2,  # Number of epochs with no improvement after which training will be stopped
#     #restore_best_weights=True  # Restore weights to the best model observed during training
# )


vae.fit(
    train_data,
    epochs=50,
    batch_size=32,
    validation_data=(test_data,None),  # Provide validation data here
    #callbacks=[early_stopping_callback],
)
# Out:
# Epoch 1/50
# 1969/1969 [==============================] - 12s 5ms/step - loss: 0.8599 - reconstruction_loss_cont: 0.5738 - reconstruction_loss_class: 0.8765 - kl_loss: 0.2583 - sparse_categorical_crossentropy: 0.8765 - val_loss: 4.4818
# Epoch 2/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.6211 - reconstruction_loss_cont: 0.2482 - reconstruction_loss_class: 0.3751 - kl_loss: 0.3422 - sparse_categorical_crossentropy: 0.3751 - val_loss: 4.7124
# Epoch 3/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5932 - reconstruction_loss_cont: 0.2352 - reconstruction_loss_class: 0.2502 - kl_loss: 0.3548 - sparse_categorical_crossentropy: 0.2502 - val_loss: 4.9490
# Epoch 4/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5878 - reconstruction_loss_cont: 0.2312 - reconstruction_loss_class: 0.2163 - kl_loss: 0.3581 - sparse_categorical_crossentropy: 0.2163 - val_loss: 4.6633
# Epoch 5/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5821 - reconstruction_loss_cont: 0.2292 - reconstruction_loss_class: 0.1978 - kl_loss: 0.3583 - sparse_categorical_crossentropy: 0.1978 - val_loss: 4.5244
# Epoch 6/50
# 1969/1969 [==============================] - 14s 7ms/step - loss: 0.5796 - reconstruction_loss_cont: 0.2267 - reconstruction_loss_class: 0.1888 - kl_loss: 0.3597 - sparse_categorical_crossentropy: 0.1888 - val_loss: 4.0508
# Epoch 7/50
# 1969/1969 [==============================] - 13s 7ms/step - loss: 0.5757 - reconstruction_loss_cont: 0.2259 - reconstruction_loss_class: 0.1807 - kl_loss: 0.3589 - sparse_categorical_crossentropy: 0.1807 - val_loss: 4.3140
# Epoch 8/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5734 - reconstruction_loss_cont: 0.2244 - reconstruction_loss_class: 0.1760 - kl_loss: 0.3588 - sparse_categorical_crossentropy: 0.1760 - val_loss: 4.1217
# Epoch 9/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5711 - reconstruction_loss_cont: 0.2238 - reconstruction_loss_class: 0.1696 - kl_loss: 0.3585 - sparse_categorical_crossentropy: 0.1696 - val_loss: 4.3323
# Epoch 10/50
# 1969/1969 [==============================] - 14s 7ms/step - loss: 0.5728 - reconstruction_loss_cont: 0.2231 - reconstruction_loss_class: 0.1692 - kl_loss: 0.3599 - sparse_categorical_crossentropy: 0.1692 - val_loss: 5.0246
# Epoch 11/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5685 - reconstruction_loss_cont: 0.2212 - reconstruction_loss_class: 0.1655 - kl_loss: 0.3599 - sparse_categorical_crossentropy: 0.1655 - val_loss: 5.4710
# Epoch 12/50
# 1969/1969 [==============================] - 14s 7ms/step - loss: 0.5696 - reconstruction_loss_cont: 0.2216 - reconstruction_loss_class: 0.1612 - kl_loss: 0.3598 - sparse_categorical_crossentropy: 0.1612 - val_loss: 4.6407
# Epoch 13/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5678 - reconstruction_loss_cont: 0.2182 - reconstruction_loss_class: 0.1603 - kl_loss: 0.3605 - sparse_categorical_crossentropy: 0.1603 - val_loss: 4.5872
# Epoch 14/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5670 - reconstruction_loss_cont: 0.2195 - reconstruction_loss_class: 0.1570 - kl_loss: 0.3587 - sparse_categorical_crossentropy: 0.1570 - val_loss: 4.3420
# Epoch 15/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5667 - reconstruction_loss_cont: 0.2210 - reconstruction_loss_class: 0.1530 - kl_loss: 0.3590 - sparse_categorical_crossentropy: 0.1530 - val_loss: 5.0456
# Epoch 16/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5665 - reconstruction_loss_cont: 0.2201 - reconstruction_loss_class: 0.1551 - kl_loss: 0.3601 - sparse_categorical_crossentropy: 0.1551 - val_loss: 4.4192
# Epoch 17/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5665 - reconstruction_loss_cont: 0.2199 - reconstruction_loss_class: 0.1527 - kl_loss: 0.3594 - sparse_categorical_crossentropy: 0.1527 - val_loss: 5.0140
# Epoch 18/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5654 - reconstruction_loss_cont: 0.2185 - reconstruction_loss_class: 0.1510 - kl_loss: 0.3600 - sparse_categorical_crossentropy: 0.1510 - val_loss: 4.4675
# Epoch 19/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5659 - reconstruction_loss_cont: 0.2204 - reconstruction_loss_class: 0.1476 - kl_loss: 0.3606 - sparse_categorical_crossentropy: 0.1476 - val_loss: 4.9645
# Epoch 20/50
# 1969/1969 [==============================] - 11s 5ms/step - loss: 0.5651 - reconstruction_loss_cont: 0.2180 - reconstruction_loss_class: 0.1493 - kl_loss: 0.3596 - sparse_categorical_crossentropy: 0.1493 - val_loss: 5.3148
# Epoch 21/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5654 - reconstruction_loss_cont: 0.2180 - reconstruction_loss_class: 0.1465 - kl_loss: 0.3618 - sparse_categorical_crossentropy: 0.1465 - val_loss: 4.4663
# Epoch 22/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5653 - reconstruction_loss_cont: 0.2183 - reconstruction_loss_class: 0.1455 - kl_loss: 0.3611 - sparse_categorical_crossentropy: 0.1455 - val_loss: 4.4950
# Epoch 23/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5652 - reconstruction_loss_cont: 0.2182 - reconstruction_loss_class: 0.1431 - kl_loss: 0.3612 - sparse_categorical_crossentropy: 0.1431 - val_loss: 4.4123
# Epoch 24/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5642 - reconstruction_loss_cont: 0.2180 - reconstruction_loss_class: 0.1452 - kl_loss: 0.3616 - sparse_categorical_crossentropy: 0.1452 - val_loss: 5.4936
# Epoch 25/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5640 - reconstruction_loss_cont: 0.2169 - reconstruction_loss_class: 0.1418 - kl_loss: 0.3620 - sparse_categorical_crossentropy: 0.1418 - val_loss: 5.1433
# Epoch 26/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5619 - reconstruction_loss_cont: 0.2155 - reconstruction_loss_class: 0.1385 - kl_loss: 0.3619 - sparse_categorical_crossentropy: 0.1385 - val_loss: 4.6668
# Epoch 27/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5632 - reconstruction_loss_cont: 0.2163 - reconstruction_loss_class: 0.1391 - kl_loss: 0.3616 - sparse_categorical_crossentropy: 0.1391 - val_loss: 4.6026
# Epoch 28/50
# 1969/1969 [==============================] - 11s 5ms/step - loss: 0.5611 - reconstruction_loss_cont: 0.2161 - reconstruction_loss_class: 0.1373 - kl_loss: 0.3610 - sparse_categorical_crossentropy: 0.1373 - val_loss: 4.5018
# Epoch 29/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5628 - reconstruction_loss_cont: 0.2164 - reconstruction_loss_class: 0.1373 - kl_loss: 0.3612 - sparse_categorical_crossentropy: 0.1373 - val_loss: 4.4449
# Epoch 30/50
# 1969/1969 [==============================] - 10s 5ms/step - loss: 0.5616 - reconstruction_loss_cont: 0.2160 - reconstruction_loss_class: 0.1378 - kl_loss: 0.3616 - sparse_categorical_crossentropy: 0.1378 - val_loss: 5.1240
# Epoch 31/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5609 - reconstruction_loss_cont: 0.2155 - reconstruction_loss_class: 0.1330 - kl_loss: 0.3616 - sparse_categorical_crossentropy: 0.1330 - val_loss: 4.3144
# Epoch 32/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5619 - reconstruction_loss_cont: 0.2138 - reconstruction_loss_class: 0.1346 - kl_loss: 0.3630 - sparse_categorical_crossentropy: 0.1346 - val_loss: 5.1631
# Epoch 33/50
# 1969/1969 [==============================] - 11s 5ms/step - loss: 0.5612 - reconstruction_loss_cont: 0.2140 - reconstruction_loss_class: 0.1338 - kl_loss: 0.3630 - sparse_categorical_crossentropy: 0.1338 - val_loss: 4.3835
# Epoch 34/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5599 - reconstruction_loss_cont: 0.2139 - reconstruction_loss_class: 0.1328 - kl_loss: 0.3623 - sparse_categorical_crossentropy: 0.1328 - val_loss: 4.7635
# Epoch 35/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5604 - reconstruction_loss_cont: 0.2131 - reconstruction_loss_class: 0.1300 - kl_loss: 0.3633 - sparse_categorical_crossentropy: 0.1300 - val_loss: 5.2636
# Epoch 36/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5589 - reconstruction_loss_cont: 0.2134 - reconstruction_loss_class: 0.1315 - kl_loss: 0.3622 - sparse_categorical_crossentropy: 0.1315 - val_loss: 5.3732
# Epoch 37/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5606 - reconstruction_loss_cont: 0.2123 - reconstruction_loss_class: 0.1306 - kl_loss: 0.3641 - sparse_categorical_crossentropy: 0.1306 - val_loss: 4.8441
# Epoch 38/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5600 - reconstruction_loss_cont: 0.2136 - reconstruction_loss_class: 0.1282 - kl_loss: 0.3638 - sparse_categorical_crossentropy: 0.1282 - val_loss: 5.0508
# Epoch 39/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5606 - reconstruction_loss_cont: 0.2141 - reconstruction_loss_class: 0.1289 - kl_loss: 0.3634 - sparse_categorical_crossentropy: 0.1289 - val_loss: 5.3229
# Epoch 40/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5609 - reconstruction_loss_cont: 0.2137 - reconstruction_loss_class: 0.1263 - kl_loss: 0.3628 - sparse_categorical_crossentropy: 0.1263 - val_loss: 4.9585
# Epoch 41/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5576 - reconstruction_loss_cont: 0.2123 - reconstruction_loss_class: 0.1253 - kl_loss: 0.3636 - sparse_categorical_crossentropy: 0.1253 - val_loss: 5.0337
# Epoch 42/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5614 - reconstruction_loss_cont: 0.2125 - reconstruction_loss_class: 0.1265 - kl_loss: 0.3649 - sparse_categorical_crossentropy: 0.1265 - val_loss: 4.8618
# Epoch 43/50
# 1969/1969 [==============================] - 12s 6ms/step - loss: 0.5587 - reconstruction_loss_cont: 0.2136 - reconstruction_loss_class: 0.1242 - kl_loss: 0.3628 - sparse_categorical_crossentropy: 0.1242 - val_loss: 5.1287
# Epoch 44/50
# 1969/1969 [==============================] - 13s 6ms/step - loss: 0.5585 - reconstruction_loss_cont: 0.2128 - reconstruction_loss_class: 0.1223 - kl_loss: 0.3648 - sparse_categorical_crossentropy: 0.1223 - val_loss: 4.5577
# Epoch 45/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5600 - reconstruction_loss_cont: 0.2129 - reconstruction_loss_class: 0.1271 - kl_loss: 0.3633 - sparse_categorical_crossentropy: 0.1271 - val_loss: 4.5197
# Epoch 46/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5600 - reconstruction_loss_cont: 0.2129 - reconstruction_loss_class: 0.1212 - kl_loss: 0.3650 - sparse_categorical_crossentropy: 0.1212 - val_loss: 5.5505
# Epoch 47/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5574 - reconstruction_loss_cont: 0.2123 - reconstruction_loss_class: 0.1202 - kl_loss: 0.3640 - sparse_categorical_crossentropy: 0.1202 - val_loss: 4.6538
# Epoch 48/50
# 1969/1969 [==============================] - 11s 5ms/step - loss: 0.5587 - reconstruction_loss_cont: 0.2122 - reconstruction_loss_class: 0.1235 - kl_loss: 0.3638 - sparse_categorical_crossentropy: 0.1235 - val_loss: 4.2402
# Epoch 49/50
# 1969/1969 [==============================] - 11s 5ms/step - loss: 0.5589 - reconstruction_loss_cont: 0.2135 - reconstruction_loss_class: 0.1228 - kl_loss: 0.3637 - sparse_categorical_crossentropy: 0.1228 - val_loss: 4.6729
# Epoch 50/50
# 1969/1969 [==============================] - 11s 6ms/step - loss: 0.5589 - reconstruction_loss_cont: 0.2115 - reconstruction_loss_class: 0.1225 - kl_loss: 0.3644 - sparse_categorical_crossentropy: 0.1225 - val_loss: 4.4504

# %%
latent_vectors = np.random.normal(size=(9000, latent_dim))

# Use the decoder to generate data
generated_data_cont, generated_data_class = vae.decoder.predict(latent_vectors)
# Out:
# 282/282 [==============================] - 0s 1ms/step

# %%
generated_data_class_transformed = np.argmax(generated_data_class, axis=1)

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = generated_data_class_transformed

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = generated_data_class_transformed

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = synthetic_array[:, 1]

# Calculate the percentage
total_points = len(first_column)
percentage = (first_column / total_points) * 100

# Plot histogram with weights
plt.hist(
    first_column,
    bins=25,
    color="g",
    alpha=0.6,
    weights=np.ones_like(first_column) / total_points * 100,
)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Percentage")
plt.show()

# %%
# Assuming iris_array is the NumPy array you obtained from the Pandas DataFrame
first_column = generated_data_cont[:, 1]

# Plot histogram
plt.hist(first_column, bins=25, color="g", alpha=0.6)
plt.title("Histogram of the First Column of Iris Dataset")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
synthetic_array[:, 1]
# Out:
# array([-0.48208146,  0.22145521, -1.10998711, ...,  0.91651691,
#         1.44295871, -0.19410446])

# %%
generated_data_cont[:, 1]
# Out:
# array([ 0.15953545, -1.0571198 , -0.1712425 , ...,  0.76000917,
#        -0.98582494, -0.64800155], dtype=float32)

# %%
from scipy.stats import entropy



entropy(
    synthetic_array[:, 1], qk=generated_data_cont[:, 1], base=2
)  # base=2 for logarithm base 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 5
#       1 from scipy.stats import entropy
# ----> 5 entropy(
#       6     synthetic_array[:, 1], qk=generated_data_cont[:, 1], base=2
#       7 )  # base=2 for logarithm base 2
#
# File c:\Users\Max_G\anaconda3\envs\var_auto\lib\site-packages\scipy\stats\_entropy.py:138, in entropy(pk, qk, base, axis)
#     136 else:
#     137     qk = np.asarray(qk)
# --> 138     pk, qk = np.broadcast_arrays(pk, qk)
#     139     qk = 1.0*qk / np.sum(qk, axis=axis, keepdims=True)
#     140     vec = special.rel_entr(pk, qk)
#
# File c:\Users\Max_G\anaconda3\envs\var_auto\lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File c:\Users\Max_G\anaconda3\envs\var_auto\lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (90000,) and arg 1 with shape (9000,).

# %%
def kl_divergence_histogram(p, q, bins=10):
    hist_p, bin_edges = np.histogram(p, bins=bins, density=True)
    hist_q, _ = np.histogram(q, bins=bin_edges, density=True)

    #kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))

    return  hist_p, hist_q

# %%
def kl_divergence_histogram(p, q, bins=10):
    hist_p, bin_edges = np.histogram(p, bins=bins, density=True)
    hist_q, _ = np.histogram(q, bins=bin_edges, density=True)

    kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))

    return kl_div, hist_p, hist_q


# Example usage
array_p = np.array([1.166388, -0.9083656, 1.0234121])
array_q = np.array([0.61383605, -0.07954051, 0.3516659])

result = kl_divergence_histogram(array_p, array_q, bins=10)
print(f"KL Divergence: {result}")
# Out:
# KL Divergence: (nan, array([1.60661648, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 3.21323297]), array([0.        , 0.        , 0.        , 1.60661648, 0.        ,
#        0.        , 1.60661648, 1.60661648, 0.        , 0.        ]))
# C:\Users\Max_G\AppData\Local\Temp\ipykernel_13972\3315841641.py:5: RuntimeWarning: divide by zero encountered in log
#   kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))
# C:\Users\Max_G\AppData\Local\Temp\ipykernel_13972\3315841641.py:5: RuntimeWarning: invalid value encountered in multiply
#   kl_div = np.sum(hist_p * np.log(hist_p / (hist_q + 1e-10)))
