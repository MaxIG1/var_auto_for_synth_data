# %% [markdown]
# Main_Branch Privacy Version

# %%
import numpy as np
from tensorflow import keras
from keras.layers import Input, Dense, Lambda, BatchNormalization
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from keras import backend as K
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras.models import save_model
from scipy.special import rel_entr
from keras.models import load_model

# %%
train_data = pd.read_csv(
    "../data/interim/privacy_testing/train_random_sample.csv")
test_data = pd.read_csv("../data/interim/split/sorted_test_data_mm.csv")
# val_data = pd.read_csv("../data/interim/split/sorted_val_data_mm.csv")

# %%
train_data_array = train_data.values
# test_data_array = test_data.values
# val_data_array = val_data.values

# %%
class Sampling(keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    def get_config(self):
        return {}

    @classmethod
    def from_config(cls, config):
        return cls()

# %%
latent_dim = 32
encoder_inputs = Input(shape=(31), name="input_layer")

n_x1 = 256
x = Dense(n_x1, activation="relu", name="h1")(encoder_inputs)
x = BatchNormalization(name="batch1")(x)
x = Dense(n_x1, activation="relu", name="h2")(x)

# Split x3 into two halves
half_size = n_x1 // 2
x1_first_half = Lambda(lambda x: x[:, :half_size], name="select_z_mean")(x)
x1_second_half = Lambda(lambda x: x[:, half_size:], name="select_z_var")(x)

z_mean = Dense(latent_dim, name="z_mean")(x1_first_half)
z_log_var = Dense(latent_dim, name="z_log_var")(x1_second_half)
z = Sampling(name="Sampling")([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# %%
keras.utils.plot_model(encoder, show_shapes=True)

# %%
# Decoder
latent_inputs = keras.Input(shape=(latent_dim,))
n_x4 = 256
x = Dense(n_x4, activation="relu", name="h4")(latent_inputs)
x = BatchNormalization(name="batch1")(x)
x = Dense(n_x4, activation="relu", name="h5")(x)
cont_decoder_outputs = Dense(30, activation = 'linear', name="cont_decoder_output")(x)
class_decoder_output = Dense(1, activation="sigmoid", name="classification_output")(x)
decoder = keras.Model(latent_inputs, [cont_decoder_outputs, class_decoder_output], name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32)]         0           []
#
#  h4 (Dense)                     (None, 256)          8448        ['input_1[0][0]']
#
#  batch1 (BatchNormalization)    (None, 256)          1024        ['h4[0][0]']
#
#  h5 (Dense)                     (None, 256)          65792       ['batch1[0][0]']
#
#  cont_decoder_output (Dense)    (None, 30)           7710        ['h5[0][0]']
#
#  classification_output (Dense)  (None, 1)            257         ['h5[0][0]']
#
# ==================================================================================================
# Total params: 83,231
# Trainable params: 82,719
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.reconstruction_loss_class_tracker = keras.metrics.Mean(
            name="reconstruction_loss_class"
        )
        self.mean_abs_diff_cont_tracker = keras.metrics.Mean(name="mean_abs_diff_cont")
        self.mean_abs_diff_class_tracker = keras.metrics.Mean(
            name="mean_abs_diff_class"
        )
        self.mean_binary_tracker = keras.metrics.Mean(name="mean_binary_value")
        self.kl_div_tracker = keras.metrics.Mean(name="kl_divergence")

    def get_config(self):
        config = super(VAE, self).get_config()
        config.update({
            'encoder': self.encoder,
            'decoder': self.decoder,
        })
        return config

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.reconstruction_loss_class_tracker,
        ]

    def call(self, inputs):
        return self.decoder(self.encoder(inputs)[2])

    def train_step(self, data):

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction_cont, reconstruction_class = self.decoder(z)

            data_cont = data[:, :30]
            data_class = data[:, 30:]  # Assuming the last column is for classification

            # Reconstruction loss for continuous outputs
            reconstruction_loss_cont = keras.losses.mean_squared_error(
                data_cont, reconstruction_cont
            )

            # Reconstruction loss for classification output
            reconstruction_loss_class = keras.losses.binary_crossentropy(
                data_class, reconstruction_class
            )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(kl_loss, axis=1)

            # Compute the KL Div between original data and reconstructed
            kl_div = tf.keras.losses.KLDivergence()(data_cont, reconstruction_cont)

            # Combine losses
            total_loss = (
                reconstruction_loss_cont + reconstruction_loss_class + 0.0001 * kl_loss
            )

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
        self.kl_div_tracker.update_state(kl_div)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
            "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "sparse_categorical_crossentropy": self.reconstruction_loss_class_tracker.result(),
            "kl_div": self.kl_div_tracker.result(),
        }

    def test_step(self, data):
        """Step run during validation."""
        if isinstance(data, tuple):
            data = data[0]  # Unpack the tuple and take the input data

        data_cont = data[
            :, :30
        ]  # Assuming the first 4 columns are for continuous variables
        data_class = data[:, 30:]  # Assuming the last column is for classification

        z_mean, z_log_var, z = self.encoder(data)

        reconstruction_cont, reconstruction_class = self.decoder(z)

        reconstruction_loss_cont = keras.losses.mean_squared_error(
            data_cont, reconstruction_cont
        )

        # Reconstruction loss for classification output
        reconstruction_loss_class = keras.losses.binary_crossentropy(
            data_class, reconstruction_class
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(kl_loss, axis=1)

        # Combine losses
        total_loss = (
            reconstruction_loss_cont + reconstruction_loss_class + 0.0001 * kl_loss
        )

        # Compute mean absolute differences and mean of binary data
        mean_abs_diff_cont = tf.reduce_mean(tf.abs(data_cont - reconstruction_cont))
        mean_abs_diff_class = tf.reduce_mean(tf.abs(data_class - reconstruction_class))
        mean_binary_value = tf.reduce_mean(
            tf.cast(reconstruction_class >= 0.5, tf.float32)
        )

        # Compute the KL Div between original data and reconstructed
        kl_div = tf.keras.losses.KLDivergence()(data_cont, reconstruction_cont)

        # Update the loss tracker
        self.total_loss_tracker.update_state(total_loss)

        # Update other metrics
        self.reconstruction_loss_tracker.update_state(reconstruction_loss_cont)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_class_tracker.update_state(reconstruction_loss_class)
        self.mean_abs_diff_cont_tracker.update_state(mean_abs_diff_cont)
        self.mean_abs_diff_class_tracker.update_state(mean_abs_diff_class)
        self.mean_binary_tracker.update_state(mean_binary_value)
        self.kl_div_tracker.update_state(kl_div)

        # Return a dict mapping metric names to current value
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss_cont": self.reconstruction_loss_tracker.result(),
            "reconstruction_loss_class": self.reconstruction_loss_class_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "mean_abs_diff_cont": self.mean_abs_diff_cont_tracker.result(),
            "mean_abs_diff_class": self.mean_abs_diff_class_tracker.result(),
            "mean_binary_value": self.mean_binary_tracker.result(),
            "kl_div": self.kl_div_tracker.result(),
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())

# %%
epoch = 300

# %%
early_stopping_callback = EarlyStopping(
    monitor='val_loss',  # Monitoring validation loss
    patience=5,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore weights to the best model observed during training
)

# # Define the directory to save the model
# model_dir = "saved_model/"

# # Define a TensorBoard callback for training logs
# tensorboard_callback = TensorBoard(log_dir="logs/vae_optimized_263")

# # # Define a ModelCheckpoint callback to save the model
# # checkpoint_callback = ModelCheckpoint(
# #     filepath=model_dir, save_best_only=True, monitor="val_loss", mode="min"
# # )
# #tensorboard_callback
call_back_list = [early_stopping_callback]

hist = vae.fit(
    train_data_array,
    epochs=epoch,
    batch_size=32,
    # validation_data=(val_data_array, None), 
    # callbacks=call_back_list,
)
# Out:
# Epoch 1/300
# 890/890 [==============================] - 3s 3ms/step - loss: 0.0531 - reconstruction_loss_cont: 0.0248 - reconstruction_loss_class: 0.0077 - kl_loss: 2.7585 - sparse_categorical_crossentropy: 0.0281 - kl_div: 4.8987
# Epoch 2/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0020 - reconstruction_loss_cont: 0.0016 - reconstruction_loss_class: 4.2476e-05 - kl_loss: 3.2178 - sparse_categorical_crossentropy: 6.9819e-05 - kl_div: 0.6965
# Epoch 3/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0014 - reconstruction_loss_cont: 0.0010 - reconstruction_loss_class: 2.3819e-05 - kl_loss: 3.2955 - sparse_categorical_crossentropy: 2.6217e-05 - kl_div: 0.4320
# Epoch 4/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0010 - reconstruction_loss_cont: 6.6655e-04 - reconstruction_loss_class: 1.6699e-05 - kl_loss: 3.3059 - sparse_categorical_crossentropy: 1.8342e-05 - kl_div: 0.3189
# Epoch 5/300
# 890/890 [==============================] - 2s 3ms/step - loss: 8.4083e-04 - reconstruction_loss_cont: 5.0133e-04 - reconstruction_loss_class: 1.4663e-05 - kl_loss: 3.2220 - sparse_categorical_crossentropy: 1.4820e-05 - kl_div: 0.2543
# Epoch 6/300
# 890/890 [==============================] - 2s 2ms/step - loss: 7.6492e-04 - reconstruction_loss_cont: 4.3839e-04 - reconstruction_loss_class: 1.0226e-05 - kl_loss: 3.1118 - sparse_categorical_crossentropy: 1.1769e-05 - kl_div: 0.2129
# Epoch 7/300
# 890/890 [==============================] - 2s 2ms/step - loss: 6.7789e-04 - reconstruction_loss_cont: 3.7033e-04 - reconstruction_loss_class: 7.3383e-06 - kl_loss: 2.9585 - sparse_categorical_crossentropy: 8.0242e-06 - kl_div: 0.1839
# Epoch 8/300
# 890/890 [==============================] - 2s 2ms/step - loss: 6.2122e-04 - reconstruction_loss_cont: 3.2631e-04 - reconstruction_loss_class: 1.1174e-05 - kl_loss: 2.8632 - sparse_categorical_crossentropy: 8.0294e-06 - kl_div: 0.1624
# Epoch 9/300
# 890/890 [==============================] - 2s 2ms/step - loss: 5.3438e-04 - reconstruction_loss_cont: 2.5426e-04 - reconstruction_loss_class: 4.1155e-06 - kl_loss: 2.7306 - sparse_categorical_crossentropy: 4.3297e-06 - kl_div: 0.1457
# Epoch 10/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.9302e-04 - reconstruction_loss_cont: 2.2388e-04 - reconstruction_loss_class: 3.3476e-06 - kl_loss: 2.6141 - sparse_categorical_crossentropy: 4.0623e-06 - kl_div: 0.1323
# Epoch 11/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.5498e-04 - reconstruction_loss_cont: 2.0164e-04 - reconstruction_loss_class: 2.7348e-06 - kl_loss: 2.4824 - sparse_categorical_crossentropy: 2.7080e-06 - kl_div: 0.1213
# Epoch 12/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.1332e-04 - reconstruction_loss_cont: 1.7000e-04 - reconstruction_loss_class: 2.3302e-06 - kl_loss: 2.3845 - sparse_categorical_crossentropy: 2.3871e-06 - kl_div: 0.1122
# Epoch 13/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.6619e-04 - reconstruction_loss_cont: 1.3711e-04 - reconstruction_loss_class: 1.7456e-06 - kl_loss: 2.2441 - sparse_categorical_crossentropy: 1.4798e-06 - kl_div: 0.1043
# Epoch 14/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.4961e-04 - reconstruction_loss_cont: 1.3330e-04 - reconstruction_loss_class: 1.3847e-06 - kl_loss: 2.1173 - sparse_categorical_crossentropy: 1.3692e-06 - kl_div: 0.0975
# Epoch 15/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.2974e-04 - reconstruction_loss_cont: 1.2727e-04 - reconstruction_loss_class: 1.1035e-06 - kl_loss: 1.9722 - sparse_categorical_crossentropy: 1.1835e-06 - kl_div: 0.0914
# Epoch 16/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.0787e-04 - reconstruction_loss_cont: 1.2008e-04 - reconstruction_loss_class: 1.2259e-06 - kl_loss: 1.8407 - sparse_categorical_crossentropy: 1.0513e-06 - kl_div: 0.0862
# Epoch 17/300
# 890/890 [==============================] - 3s 3ms/step - loss: 2.9250e-04 - reconstruction_loss_cont: 1.1446e-04 - reconstruction_loss_class: 8.3532e-07 - kl_loss: 1.7534 - sparse_categorical_crossentropy: 7.6472e-07 - kl_div: 0.0815
# Epoch 18/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.0503e-04 - reconstruction_loss_cont: 1.5178e-04 - reconstruction_loss_class: 0.0030 - kl_loss: 1.9227 - sparse_categorical_crossentropy: 8.2960e-05 - kl_div: 0.0775
# Epoch 19/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0037 - reconstruction_loss_cont: 0.0026 - reconstruction_loss_class: 1.7232e-04 - kl_loss: 4.2093 - sparse_categorical_crossentropy: 6.5139e-04 - kl_div: 0.0815
# Epoch 20/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0013 - reconstruction_loss_cont: 9.9933e-04 - reconstruction_loss_class: 3.6368e-06 - kl_loss: 2.8286 - sparse_categorical_crossentropy: 4.0936e-06 - kl_div: 0.0805
# Epoch 21/300
# 890/890 [==============================] - 2s 3ms/step - loss: 8.9413e-04 - reconstruction_loss_cont: 6.3584e-04 - reconstruction_loss_class: 2.7423e-06 - kl_loss: 2.5091 - sparse_categorical_crossentropy: 3.0171e-06 - kl_div: 0.0786
# Epoch 22/300
# 890/890 [==============================] - 2s 3ms/step - loss: 6.9184e-04 - reconstruction_loss_cont: 4.5079e-04 - reconstruction_loss_class: 2.3187e-06 - kl_loss: 2.3542 - sparse_categorical_crossentropy: 2.4312e-06 - kl_div: 0.0761
# Epoch 23/300
# 890/890 [==============================] - 2s 3ms/step - loss: 5.9634e-04 - reconstruction_loss_cont: 3.6813e-04 - reconstruction_loss_class: 2.2618e-06 - kl_loss: 2.2341 - sparse_categorical_crossentropy: 2.3031e-06 - kl_div: 0.0737
# Epoch 24/300
# 890/890 [==============================] - 2s 3ms/step - loss: 5.2784e-04 - reconstruction_loss_cont: 3.0963e-04 - reconstruction_loss_class: 2.1803e-06 - kl_loss: 2.1367 - sparse_categorical_crossentropy: 2.0971e-06 - kl_div: 0.0714
# Epoch 25/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.7052e-04 - reconstruction_loss_cont: 2.6251e-04 - reconstruction_loss_class: 1.8394e-06 - kl_loss: 2.0384 - sparse_categorical_crossentropy: 1.8529e-06 - kl_div: 0.0692
# Epoch 26/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.3118e-04 - reconstruction_loss_cont: 2.3115e-04 - reconstruction_loss_class: 4.6422e-06 - kl_loss: 1.9950 - sparse_categorical_crossentropy: 2.0361e-06 - kl_div: 0.0671
# Epoch 27/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.3906e-04 - reconstruction_loss_cont: 2.3887e-04 - reconstruction_loss_class: 1.8252e-06 - kl_loss: 1.9537 - sparse_categorical_crossentropy: 1.8635e-06 - kl_div: 0.0653
# Epoch 28/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.6269e-04 - reconstruction_loss_cont: 1.6984e-04 - reconstruction_loss_class: 1.0011e-06 - kl_loss: 1.9147 - sparse_categorical_crossentropy: 1.0697e-06 - kl_div: 0.0634
# Epoch 29/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.4642e-04 - reconstruction_loss_cont: 1.5415e-04 - reconstruction_loss_class: 9.0714e-07 - kl_loss: 1.8897 - sparse_categorical_crossentropy: 9.7033e-07 - kl_div: 0.0616
# Epoch 30/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.3337e-04 - reconstruction_loss_cont: 1.4674e-04 - reconstruction_loss_class: 9.3934e-07 - kl_loss: 1.8446 - sparse_categorical_crossentropy: 1.1057e-06 - kl_div: 0.0600
# Epoch 31/300
# 890/890 [==============================] - 3s 3ms/step - loss: 3.0869e-04 - reconstruction_loss_cont: 1.2609e-04 - reconstruction_loss_class: 8.6308e-07 - kl_loss: 1.8069 - sparse_categorical_crossentropy: 7.7657e-07 - kl_div: 0.0584
# Epoch 32/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.9759e-04 - reconstruction_loss_cont: 1.1963e-04 - reconstruction_loss_class: 6.9563e-07 - kl_loss: 1.7647 - sparse_categorical_crossentropy: 6.3478e-07 - kl_div: 0.0569
# Epoch 33/300
# 890/890 [==============================] - 3s 3ms/step - loss: 2.9339e-04 - reconstruction_loss_cont: 1.1794e-04 - reconstruction_loss_class: 7.6513e-07 - kl_loss: 1.7265 - sparse_categorical_crossentropy: 1.1992e-06 - kl_div: 0.0554
# Epoch 34/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.7733e-04 - reconstruction_loss_cont: 1.0808e-04 - reconstruction_loss_class: 6.2502e-07 - kl_loss: 1.6771 - sparse_categorical_crossentropy: 5.5603e-07 - kl_div: 0.0541
# Epoch 35/300
# 890/890 [==============================] - 3s 3ms/step - loss: 0.0119 - reconstruction_loss_cont: 0.0037 - reconstruction_loss_class: 0.0080 - kl_loss: 12.2452 - sparse_categorical_crossentropy: 0.0074 - kl_div: 0.0585
# Epoch 36/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0035 - reconstruction_loss_cont: 0.0020 - reconstruction_loss_class: 2.2877e-04 - kl_loss: 8.8541 - sparse_categorical_crossentropy: 5.3442e-04 - kl_div: 0.0624
# Epoch 37/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0019 - reconstruction_loss_cont: 0.0013 - reconstruction_loss_class: 2.3083e-05 - kl_loss: 4.6050 - sparse_categorical_crossentropy: 2.6478e-05 - kl_div: 0.0626
# Epoch 38/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0014 - reconstruction_loss_cont: 0.0011 - reconstruction_loss_class: 1.5370e-05 - kl_loss: 2.8722 - sparse_categorical_crossentropy: 1.6957e-05 - kl_div: 0.0623
# Epoch 39/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0011 - reconstruction_loss_cont: 8.8723e-04 - reconstruction_loss_class: 5.9134e-06 - kl_loss: 2.3213 - sparse_categorical_crossentropy: 8.7432e-06 - kl_div: 0.0619
# Epoch 40/300
# 890/890 [==============================] - 2s 3ms/step - loss: 8.1460e-04 - reconstruction_loss_cont: 5.9821e-04 - reconstruction_loss_class: 3.1294e-06 - kl_loss: 2.0884 - sparse_categorical_crossentropy: 3.2036e-06 - kl_div: 0.0613
# Epoch 41/300
# 890/890 [==============================] - 2s 3ms/step - loss: 6.5492e-04 - reconstruction_loss_cont: 4.5416e-04 - reconstruction_loss_class: 2.5795e-06 - kl_loss: 1.9468 - sparse_categorical_crossentropy: 2.9362e-06 - kl_div: 0.0604
# Epoch 42/300
# 890/890 [==============================] - 2s 3ms/step - loss: 5.6899e-04 - reconstruction_loss_cont: 3.7972e-04 - reconstruction_loss_class: 2.1815e-06 - kl_loss: 1.8528 - sparse_categorical_crossentropy: 2.2792e-06 - kl_div: 0.0594
# Epoch 43/300
# 890/890 [==============================] - 2s 3ms/step - loss: 5.1766e-04 - reconstruction_loss_cont: 3.3442e-04 - reconstruction_loss_class: 1.8125e-06 - kl_loss: 1.8047 - sparse_categorical_crossentropy: 2.0014e-06 - kl_div: 0.0585
# Epoch 44/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.6996e-04 - reconstruction_loss_cont: 2.9069e-04 - reconstruction_loss_class: 1.6980e-06 - kl_loss: 1.7684 - sparse_categorical_crossentropy: 1.6623e-06 - kl_div: 0.0575
# Epoch 45/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.3062e-04 - reconstruction_loss_cont: 2.5499e-04 - reconstruction_loss_class: 1.3716e-06 - kl_loss: 1.7376 - sparse_categorical_crossentropy: 1.4481e-06 - kl_div: 0.0566
# Epoch 46/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.9936e-04 - reconstruction_loss_cont: 2.2700e-04 - reconstruction_loss_class: 1.1399e-06 - kl_loss: 1.7016 - sparse_categorical_crossentropy: 1.4176e-06 - kl_div: 0.0556
# Epoch 47/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.7371e-04 - reconstruction_loss_cont: 2.0530e-04 - reconstruction_loss_class: 1.3970e-06 - kl_loss: 1.6756 - sparse_categorical_crossentropy: 1.0130e-06 - kl_div: 0.0547
# Epoch 48/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.5622e-04 - reconstruction_loss_cont: 1.9256e-04 - reconstruction_loss_class: 7.0040e-07 - kl_loss: 1.6153 - sparse_categorical_crossentropy: 7.3368e-07 - kl_div: 0.0539
# Epoch 49/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.3902e-04 - reconstruction_loss_cont: 1.8021e-04 - reconstruction_loss_class: 7.4531e-07 - kl_loss: 1.5736 - sparse_categorical_crossentropy: 7.2199e-07 - kl_div: 0.0530
# Epoch 50/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.9764e-04 - reconstruction_loss_cont: 2.2228e-04 - reconstruction_loss_class: 0.0014 - kl_loss: 1.8495 - sparse_categorical_crossentropy: 1.1821e-04 - kl_div: 0.0523
# Epoch 51/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0011 - reconstruction_loss_cont: 7.9617e-04 - reconstruction_loss_class: 3.9996e-04 - kl_loss: 2.6896 - sparse_categorical_crossentropy: 4.9797e-05 - kl_div: 0.0526
# Epoch 52/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0042 - reconstruction_loss_cont: 0.0018 - reconstruction_loss_class: 5.4340e-04 - kl_loss: 3.2684 - sparse_categorical_crossentropy: 0.0020 - kl_div: 0.0535
# Epoch 53/300
# 890/890 [==============================] - 2s 3ms/step - loss: 9.6609e-04 - reconstruction_loss_cont: 6.9658e-04 - reconstruction_loss_class: 2.2206e-06 - kl_loss: 2.5773 - sparse_categorical_crossentropy: 2.3979e-06 - kl_div: 0.0532
# Epoch 54/300
# 890/890 [==============================] - 2s 3ms/step - loss: 7.2813e-04 - reconstruction_loss_cont: 4.9176e-04 - reconstruction_loss_class: 1.7469e-06 - kl_loss: 2.2971 - sparse_categorical_crossentropy: 1.8618e-06 - kl_div: 0.0527
# Epoch 55/300
# 890/890 [==============================] - 2s 3ms/step - loss: 6.0334e-04 - reconstruction_loss_cont: 3.8896e-04 - reconstruction_loss_class: 1.4627e-06 - kl_loss: 2.0753 - sparse_categorical_crossentropy: 1.5673e-06 - kl_div: 0.0521
# Epoch 56/300
# 890/890 [==============================] - 2s 3ms/step - loss: 5.3384e-04 - reconstruction_loss_cont: 3.3563e-04 - reconstruction_loss_class: 1.2372e-06 - kl_loss: 1.9410 - sparse_categorical_crossentropy: 1.2901e-06 - kl_div: 0.0514
# Epoch 57/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.8933e-04 - reconstruction_loss_cont: 3.0211e-04 - reconstruction_loss_class: 1.0758e-06 - kl_loss: 1.8332 - sparse_categorical_crossentropy: 1.0954e-06 - kl_div: 0.0508
# Epoch 58/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.6177e-04 - reconstruction_loss_cont: 2.8377e-04 - reconstruction_loss_class: 1.0236e-06 - kl_loss: 1.7512 - sparse_categorical_crossentropy: 1.0142e-06 - kl_div: 0.0502
# Epoch 59/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.5248e-04 - reconstruction_loss_cont: 2.8146e-04 - reconstruction_loss_class: 9.1381e-07 - kl_loss: 1.6791 - sparse_categorical_crossentropy: 9.4840e-07 - kl_div: 0.0496
# Epoch 60/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.3528e-04 - reconstruction_loss_cont: 2.7253e-04 - reconstruction_loss_class: 9.3754e-07 - kl_loss: 1.6001 - sparse_categorical_crossentropy: 9.1496e-07 - kl_div: 0.0490
# Epoch 61/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.3292e-04 - reconstruction_loss_cont: 2.7567e-04 - reconstruction_loss_class: 1.0337e-06 - kl_loss: 1.5476 - sparse_categorical_crossentropy: 1.2413e-06 - kl_div: 0.0484
# Epoch 62/300
# 890/890 [==============================] - 3s 3ms/step - loss: 4.1281e-04 - reconstruction_loss_cont: 2.6144e-04 - reconstruction_loss_class: 6.9746e-07 - kl_loss: 1.4964 - sparse_categorical_crossentropy: 7.0874e-07 - kl_div: 0.0478
# Epoch 63/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.9671e-04 - reconstruction_loss_cont: 2.5037e-04 - reconstruction_loss_class: 7.4031e-07 - kl_loss: 1.4456 - sparse_categorical_crossentropy: 7.7752e-07 - kl_div: 0.0473
# Epoch 64/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.8153e-04 - reconstruction_loss_cont: 2.3964e-04 - reconstruction_loss_class: 4.7297e-07 - kl_loss: 1.4032 - sparse_categorical_crossentropy: 5.0216e-07 - kl_div: 0.0467
# Epoch 65/300
# 890/890 [==============================] - 3s 3ms/step - loss: 3.6869e-04 - reconstruction_loss_cont: 2.3131e-04 - reconstruction_loss_class: 5.0565e-07 - kl_loss: 1.3612 - sparse_categorical_crossentropy: 5.0820e-07 - kl_div: 0.0462
# Epoch 66/300
# 890/890 [==============================] - 3s 3ms/step - loss: 3.6089e-04 - reconstruction_loss_cont: 2.2784e-04 - reconstruction_loss_class: 4.4227e-07 - kl_loss: 1.3160 - sparse_categorical_crossentropy: 4.3519e-07 - kl_div: 0.0457
# Epoch 67/300
# 890/890 [==============================] - 3s 3ms/step - loss: 3.5495e-04 - reconstruction_loss_cont: 2.2585e-04 - reconstruction_loss_class: 5.0853e-07 - kl_loss: 1.2748 - sparse_categorical_crossentropy: 4.7938e-07 - kl_div: 0.0452
# Epoch 68/300
# 890/890 [==============================] - 3s 3ms/step - loss: 3.3967e-04 - reconstruction_loss_cont: 2.1482e-04 - reconstruction_loss_class: 2.6148e-07 - kl_loss: 1.2437 - sparse_categorical_crossentropy: 2.5664e-07 - kl_div: 0.0447
# Epoch 69/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.3355e-04 - reconstruction_loss_cont: 2.1062e-04 - reconstruction_loss_class: 2.1918e-07 - kl_loss: 1.2250 - sparse_categorical_crossentropy: 1.8876e-07 - kl_div: 0.0442
# Epoch 70/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.2461e-04 - reconstruction_loss_cont: 2.0264e-04 - reconstruction_loss_class: 2.4919e-07 - kl_loss: 1.2126 - sparse_categorical_crossentropy: 2.0822e-07 - kl_div: 0.0438
# Epoch 71/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1124e-04 - reconstruction_loss_cont: 1.9080e-04 - reconstruction_loss_class: 6.3186e-06 - kl_loss: 1.2204 - sparse_categorical_crossentropy: 3.4153e-07 - kl_div: 0.0433
# Epoch 72/300
# 890/890 [==============================] - 2s 2ms/step - loss: 6.9524e-04 - reconstruction_loss_cont: 5.2497e-04 - reconstruction_loss_class: 3.0985e-06 - kl_loss: 1.3381 - sparse_categorical_crossentropy: 1.9799e-05 - kl_div: 0.0430
# Epoch 73/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1023e-04 - reconstruction_loss_cont: 1.8628e-04 - reconstruction_loss_class: 2.6797e-07 - kl_loss: 1.2330 - sparse_categorical_crossentropy: 2.6820e-07 - kl_div: 0.0425
# Epoch 74/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9556e-04 - reconstruction_loss_cont: 1.7332e-04 - reconstruction_loss_class: 2.0899e-07 - kl_loss: 1.2123 - sparse_categorical_crossentropy: 2.2577e-07 - kl_div: 0.0421
# Epoch 75/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9527e-04 - reconstruction_loss_cont: 1.7536e-04 - reconstruction_loss_class: 1.7618e-07 - kl_loss: 1.1923 - sparse_categorical_crossentropy: 1.8022e-07 - kl_div: 0.0417
# Epoch 76/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9325e-04 - reconstruction_loss_cont: 1.7480e-04 - reconstruction_loss_class: 1.5496e-07 - kl_loss: 1.1788 - sparse_categorical_crossentropy: 1.5872e-07 - kl_div: 0.0413
# Epoch 77/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.8667e-04 - reconstruction_loss_cont: 1.6980e-04 - reconstruction_loss_class: 2.2815e-07 - kl_loss: 1.1621 - sparse_categorical_crossentropy: 1.6555e-07 - kl_div: 0.0409
# Epoch 78/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9198e-04 - reconstruction_loss_cont: 1.7629e-04 - reconstruction_loss_class: 1.6435e-07 - kl_loss: 1.1490 - sparse_categorical_crossentropy: 1.5427e-07 - kl_div: 0.0405
# Epoch 79/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.8347e-04 - reconstruction_loss_cont: 1.6928e-04 - reconstruction_loss_class: 2.6402e-07 - kl_loss: 1.1364 - sparse_categorical_crossentropy: 2.4645e-07 - kl_div: 0.0401
# Epoch 80/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7530e-04 - reconstruction_loss_cont: 1.6263e-04 - reconstruction_loss_class: 1.8830e-07 - kl_loss: 1.1220 - sparse_categorical_crossentropy: 2.0889e-07 - kl_div: 0.0398
# Epoch 81/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6890e-04 - reconstruction_loss_cont: 1.5714e-04 - reconstruction_loss_class: 1.3939e-07 - kl_loss: 1.1130 - sparse_categorical_crossentropy: 1.8800e-07 - kl_div: 0.0394
# Epoch 82/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6963e-04 - reconstruction_loss_cont: 1.5923e-04 - reconstruction_loss_class: 2.1145e-07 - kl_loss: 1.1015 - sparse_categorical_crossentropy: 2.2936e-07 - kl_div: 0.0391
# Epoch 83/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5654e-04 - reconstruction_loss_cont: 1.4695e-04 - reconstruction_loss_class: 1.9057e-07 - kl_loss: 1.0926 - sparse_categorical_crossentropy: 1.1870e-07 - kl_div: 0.0387
# Epoch 84/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5942e-04 - reconstruction_loss_cont: 1.5049e-04 - reconstruction_loss_class: 1.6984e-07 - kl_loss: 1.0841 - sparse_categorical_crossentropy: 1.9067e-07 - kl_div: 0.0384
# Epoch 85/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5006e-04 - reconstruction_loss_cont: 1.4230e-04 - reconstruction_loss_class: 1.4581e-07 - kl_loss: 1.0736 - sparse_categorical_crossentropy: 1.3889e-07 - kl_div: 0.0381
# Epoch 86/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0027 - reconstruction_loss_cont: 0.0011 - reconstruction_loss_class: 0.0021 - kl_loss: 3.7262 - sparse_categorical_crossentropy: 0.0013 - kl_div: 0.0383
# Epoch 87/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0019 - reconstruction_loss_cont: 0.0016 - reconstruction_loss_class: 1.8454e-05 - kl_loss: 3.0539 - sparse_categorical_crossentropy: 2.5575e-05 - kl_div: 0.0395
# Epoch 88/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0015 - reconstruction_loss_cont: 0.0012 - reconstruction_loss_class: 5.6121e-06 - kl_loss: 2.1991 - sparse_categorical_crossentropy: 6.4056e-06 - kl_div: 0.0397
# Epoch 89/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0012 - reconstruction_loss_cont: 0.0010 - reconstruction_loss_class: 3.9802e-06 - kl_loss: 1.6584 - sparse_categorical_crossentropy: 4.9292e-06 - kl_div: 0.0398
# Epoch 90/300
# 890/890 [==============================] - 2s 2ms/step - loss: 8.6948e-04 - reconstruction_loss_cont: 7.1956e-04 - reconstruction_loss_class: 2.2160e-06 - kl_loss: 1.4469 - sparse_categorical_crossentropy: 2.8185e-06 - kl_div: 0.0398
# Epoch 91/300
# 890/890 [==============================] - 2s 2ms/step - loss: 6.1364e-04 - reconstruction_loss_cont: 4.7305e-04 - reconstruction_loss_class: 1.4034e-06 - kl_loss: 1.3844 - sparse_categorical_crossentropy: 1.2687e-06 - kl_div: 0.0397
# Epoch 92/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.8943e-04 - reconstruction_loss_cont: 3.5401e-04 - reconstruction_loss_class: 1.0951e-06 - kl_loss: 1.3351 - sparse_categorical_crossentropy: 9.7408e-07 - kl_div: 0.0395
# Epoch 93/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.3512e-04 - reconstruction_loss_cont: 3.0471e-04 - reconstruction_loss_class: 5.3510e-07 - kl_loss: 1.2935 - sparse_categorical_crossentropy: 5.8650e-07 - kl_div: 0.0392
# Epoch 94/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.7186e-04 - reconstruction_loss_cont: 2.4503e-04 - reconstruction_loss_class: 4.8135e-07 - kl_loss: 1.2485 - sparse_categorical_crossentropy: 5.0725e-07 - kl_div: 0.0390
# Epoch 95/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.4143e-04 - reconstruction_loss_cont: 2.1905e-04 - reconstruction_loss_class: 4.2974e-07 - kl_loss: 1.2119 - sparse_categorical_crossentropy: 4.5455e-07 - kl_div: 0.0387
# Epoch 96/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1911e-04 - reconstruction_loss_cont: 2.0049e-04 - reconstruction_loss_class: 4.3650e-07 - kl_loss: 1.1732 - sparse_categorical_crossentropy: 3.8462e-07 - kl_div: 0.0385
# Epoch 97/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1446e-04 - reconstruction_loss_cont: 1.9910e-04 - reconstruction_loss_class: 3.9307e-07 - kl_loss: 1.1457 - sparse_categorical_crossentropy: 4.0513e-07 - kl_div: 0.0382
# Epoch 98/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.0785e-04 - reconstruction_loss_cont: 1.9463e-04 - reconstruction_loss_class: 4.0417e-07 - kl_loss: 1.1230 - sparse_categorical_crossentropy: 4.0779e-07 - kl_div: 0.0380
# Epoch 99/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1330e-04 - reconstruction_loss_cont: 1.9987e-04 - reconstruction_loss_class: 1.1473e-06 - kl_loss: 1.1274 - sparse_categorical_crossentropy: 1.0324e-06 - kl_div: 0.0377
# Epoch 100/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1233e-04 - reconstruction_loss_cont: 2.0057e-04 - reconstruction_loss_class: 3.0756e-07 - kl_loss: 1.1005 - sparse_categorical_crossentropy: 4.9356e-07 - kl_div: 0.0375
# Epoch 101/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.8819e-04 - reconstruction_loss_cont: 1.7985e-04 - reconstruction_loss_class: 2.0011e-07 - kl_loss: 1.0794 - sparse_categorical_crossentropy: 1.9759e-07 - kl_div: 0.0372
# Epoch 102/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.8700e-04 - reconstruction_loss_cont: 1.7984e-04 - reconstruction_loss_class: 2.5780e-07 - kl_loss: 1.0664 - sparse_categorical_crossentropy: 2.3271e-07 - kl_div: 0.0370
# Epoch 103/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.9064e-04 - reconstruction_loss_cont: 1.8448e-04 - reconstruction_loss_class: 3.1567e-07 - kl_loss: 1.0568 - sparse_categorical_crossentropy: 2.4335e-07 - kl_div: 0.0368
# Epoch 104/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7664e-04 - reconstruction_loss_cont: 1.7152e-04 - reconstruction_loss_class: 2.0973e-07 - kl_loss: 1.0470 - sparse_categorical_crossentropy: 1.6219e-07 - kl_div: 0.0365
# Epoch 105/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7375e-04 - reconstruction_loss_cont: 1.6967e-04 - reconstruction_loss_class: 1.5977e-07 - kl_loss: 1.0359 - sparse_categorical_crossentropy: 1.7209e-07 - kl_div: 0.0363
# Epoch 106/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7868e-04 - reconstruction_loss_cont: 1.7533e-04 - reconstruction_loss_class: 8.7976e-07 - kl_loss: 1.0312 - sparse_categorical_crossentropy: 1.8072e-07 - kl_div: 0.0361
# Epoch 107/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7854e-04 - reconstruction_loss_cont: 1.7496e-04 - reconstruction_loss_class: 1.3675e-07 - kl_loss: 1.0262 - sparse_categorical_crossentropy: 2.4124e-07 - kl_div: 0.0358
# Epoch 108/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6597e-04 - reconstruction_loss_cont: 1.6382e-04 - reconstruction_loss_class: 1.0579e-07 - kl_loss: 1.0180 - sparse_categorical_crossentropy: 1.1727e-07 - kl_div: 0.0356
# Epoch 109/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6702e-04 - reconstruction_loss_cont: 1.6582e-04 - reconstruction_loss_class: 1.1914e-07 - kl_loss: 1.0111 - sparse_categorical_crossentropy: 1.0345e-07 - kl_div: 0.0354
# Epoch 110/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6382e-04 - reconstruction_loss_cont: 1.6330e-04 - reconstruction_loss_class: 1.0542e-07 - kl_loss: 1.0034 - sparse_categorical_crossentropy: 1.0241e-07 - kl_div: 0.0352
# Epoch 111/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6171e-04 - reconstruction_loss_cont: 1.6176e-04 - reconstruction_loss_class: 1.4275e-07 - kl_loss: 0.9974 - sparse_categorical_crossentropy: 1.4312e-07 - kl_div: 0.0350
# Epoch 112/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6009e-04 - reconstruction_loss_cont: 1.6065e-04 - reconstruction_loss_class: 1.0849e-07 - kl_loss: 0.9923 - sparse_categorical_crossentropy: 1.0449e-07 - kl_div: 0.0347
# Epoch 113/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5761e-04 - reconstruction_loss_cont: 1.5844e-04 - reconstruction_loss_class: 4.0217e-07 - kl_loss: 0.9904 - sparse_categorical_crossentropy: 1.1541e-07 - kl_div: 0.0345
# Epoch 114/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5349e-04 - reconstruction_loss_cont: 1.5446e-04 - reconstruction_loss_class: 8.7703e-08 - kl_loss: 0.9882 - sparse_categorical_crossentropy: 7.5105e-08 - kl_div: 0.0343
# Epoch 115/300
# 890/890 [==============================] - 2s 2ms/step - loss: 6.8295e-04 - reconstruction_loss_cont: 2.0686e-04 - reconstruction_loss_class: 6.7187e-04 - kl_loss: 1.2893 - sparse_categorical_crossentropy: 3.6734e-04 - kl_div: 0.0342
# Epoch 116/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.8677e-04 - reconstruction_loss_cont: 2.5786e-04 - reconstruction_loss_class: 8.1175e-07 - kl_loss: 1.2454 - sparse_categorical_crossentropy: 1.1273e-06 - kl_div: 0.0340
# Epoch 117/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.1317e-04 - reconstruction_loss_cont: 1.9421e-04 - reconstruction_loss_class: 3.4877e-07 - kl_loss: 1.1711 - sparse_categorical_crossentropy: 3.6615e-07 - kl_div: 0.0338
# Epoch 118/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.8698e-04 - reconstruction_loss_cont: 1.7342e-04 - reconstruction_loss_class: 2.3963e-07 - kl_loss: 1.1243 - sparse_categorical_crossentropy: 2.1297e-07 - kl_div: 0.0337
# Epoch 119/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6626e-04 - reconstruction_loss_cont: 1.5598e-04 - reconstruction_loss_class: 2.2659e-07 - kl_loss: 1.0936 - sparse_categorical_crossentropy: 2.3114e-07 - kl_div: 0.0335
# Epoch 120/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5757e-04 - reconstruction_loss_cont: 1.5025e-04 - reconstruction_loss_class: 2.1744e-07 - kl_loss: 1.0690 - sparse_categorical_crossentropy: 2.2040e-07 - kl_div: 0.0333
# Epoch 121/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5545e-04 - reconstruction_loss_cont: 1.4913e-04 - reconstruction_loss_class: 2.0032e-07 - kl_loss: 1.0568 - sparse_categorical_crossentropy: 2.1685e-07 - kl_div: 0.0331
# Epoch 122/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4672e-04 - reconstruction_loss_cont: 1.4174e-04 - reconstruction_loss_class: 2.0909e-07 - kl_loss: 1.0467 - sparse_categorical_crossentropy: 2.4501e-07 - kl_div: 0.0329
# Epoch 123/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4328e-04 - reconstruction_loss_cont: 1.3882e-04 - reconstruction_loss_class: 2.2249e-07 - kl_loss: 1.0436 - sparse_categorical_crossentropy: 2.2140e-07 - kl_div: 0.0327
# Epoch 124/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.3815e-04 - reconstruction_loss_cont: 1.3431e-04 - reconstruction_loss_class: 2.0452e-07 - kl_loss: 1.0381 - sparse_categorical_crossentropy: 1.8908e-07 - kl_div: 0.0326
# Epoch 125/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.3533e-04 - reconstruction_loss_cont: 1.3138e-04 - reconstruction_loss_class: 1.8779e-07 - kl_loss: 1.0364 - sparse_categorical_crossentropy: 1.8751e-07 - kl_div: 0.0324
# Epoch 126/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.3733e-04 - reconstruction_loss_cont: 1.3390e-04 - reconstruction_loss_class: 1.7197e-07 - kl_loss: 1.0329 - sparse_categorical_crossentropy: 1.8159e-07 - kl_div: 0.0322
# Epoch 127/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2894e-04 - reconstruction_loss_cont: 1.2633e-04 - reconstruction_loss_class: 1.8794e-07 - kl_loss: 1.0225 - sparse_categorical_crossentropy: 1.6357e-07 - kl_div: 0.0320
# Epoch 128/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2595e-04 - reconstruction_loss_cont: 1.2389e-04 - reconstruction_loss_class: 1.7271e-07 - kl_loss: 1.0176 - sparse_categorical_crossentropy: 1.5771e-07 - kl_div: 0.0319
# Epoch 129/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2302e-04 - reconstruction_loss_cont: 1.2161e-04 - reconstruction_loss_class: 1.5124e-07 - kl_loss: 1.0102 - sparse_categorical_crossentropy: 1.6799e-07 - kl_div: 0.0317
# Epoch 130/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2054e-04 - reconstruction_loss_cont: 1.1993e-04 - reconstruction_loss_class: 1.1789e-07 - kl_loss: 1.0044 - sparse_categorical_crossentropy: 1.1511e-07 - kl_div: 0.0315
# Epoch 131/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1775e-04 - reconstruction_loss_cont: 1.1763e-04 - reconstruction_loss_class: 1.1540e-07 - kl_loss: 0.9992 - sparse_categorical_crossentropy: 1.0827e-07 - kl_div: 0.0314
# Epoch 132/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2051e-04 - reconstruction_loss_cont: 1.2082e-04 - reconstruction_loss_class: 9.6754e-08 - kl_loss: 0.9947 - sparse_categorical_crossentropy: 9.7449e-08 - kl_div: 0.0312
# Epoch 133/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1198e-04 - reconstruction_loss_cont: 1.1256e-04 - reconstruction_loss_class: 1.5094e-07 - kl_loss: 0.9931 - sparse_categorical_crossentropy: 1.2541e-07 - kl_div: 0.0310
# Epoch 134/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.1075e-04 - reconstruction_loss_cont: 1.1195e-04 - reconstruction_loss_class: 9.7076e-08 - kl_loss: 0.9865 - sparse_categorical_crossentropy: 9.1939e-08 - kl_div: 0.0309
# Epoch 135/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.1135e-04 - reconstruction_loss_cont: 1.1296e-04 - reconstruction_loss_class: 1.0352e-07 - kl_loss: 0.9847 - sparse_categorical_crossentropy: 9.7549e-08 - kl_div: 0.0307
# Epoch 136/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0928e-04 - reconstruction_loss_cont: 1.1081e-04 - reconstruction_loss_class: 1.0320e-07 - kl_loss: 0.9821 - sparse_categorical_crossentropy: 8.7972e-08 - kl_div: 0.0305
# Epoch 137/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0991e-04 - reconstruction_loss_cont: 1.1215e-04 - reconstruction_loss_class: 9.5028e-08 - kl_loss: 0.9765 - sparse_categorical_crossentropy: 9.2482e-08 - kl_div: 0.0304
# Epoch 138/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0340e-04 - reconstruction_loss_cont: 1.0607e-04 - reconstruction_loss_class: 1.1751e-07 - kl_loss: 0.9743 - sparse_categorical_crossentropy: 5.8313e-08 - kl_div: 0.0302
# Epoch 139/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0567e-04 - reconstruction_loss_cont: 1.0857e-04 - reconstruction_loss_class: 5.2782e-08 - kl_loss: 0.9695 - sparse_categorical_crossentropy: 4.7182e-08 - kl_div: 0.0301
# Epoch 140/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1045e-04 - reconstruction_loss_cont: 1.1275e-04 - reconstruction_loss_class: 2.0528e-07 - kl_loss: 0.9720 - sparse_categorical_crossentropy: 3.5255e-07 - kl_div: 0.0299
# Epoch 141/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0199e-04 - reconstruction_loss_cont: 1.0503e-04 - reconstruction_loss_class: 7.5754e-08 - kl_loss: 0.9687 - sparse_categorical_crossentropy: 6.4449e-08 - kl_div: 0.0298
# Epoch 142/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9663e-04 - reconstruction_loss_cont: 1.0012e-04 - reconstruction_loss_class: 6.7327e-08 - kl_loss: 0.9631 - sparse_categorical_crossentropy: 8.4840e-08 - kl_div: 0.0296
# Epoch 143/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.9715e-04 - reconstruction_loss_cont: 1.0058e-04 - reconstruction_loss_class: 9.7109e-08 - kl_loss: 0.9635 - sparse_categorical_crossentropy: 8.8350e-08 - kl_div: 0.0295
# Epoch 144/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.9309e-04 - reconstruction_loss_cont: 9.6946e-05 - reconstruction_loss_class: 5.4471e-08 - kl_loss: 0.9604 - sparse_categorical_crossentropy: 5.8088e-08 - kl_div: 0.0293
# Epoch 145/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9325e-04 - reconstruction_loss_cont: 9.6982e-05 - reconstruction_loss_class: 9.5728e-08 - kl_loss: 0.9608 - sparse_categorical_crossentropy: 7.0265e-08 - kl_div: 0.0292
# Epoch 146/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9539e-04 - reconstruction_loss_cont: 9.9184e-05 - reconstruction_loss_class: 8.6788e-08 - kl_loss: 0.9594 - sparse_categorical_crossentropy: 1.5986e-07 - kl_div: 0.0290
# Epoch 147/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.8949e-04 - reconstruction_loss_cont: 9.3467e-05 - reconstruction_loss_class: 6.8949e-08 - kl_loss: 0.9576 - sparse_categorical_crossentropy: 8.7244e-08 - kl_div: 0.0289
# Epoch 148/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.8771e-04 - reconstruction_loss_cont: 9.1889e-05 - reconstruction_loss_class: 8.2539e-08 - kl_loss: 0.9570 - sparse_categorical_crossentropy: 6.2391e-08 - kl_div: 0.0288
# Epoch 149/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9138e-04 - reconstruction_loss_cont: 9.5392e-05 - reconstruction_loss_class: 1.3135e-07 - kl_loss: 0.9588 - sparse_categorical_crossentropy: 1.0456e-07 - kl_div: 0.0286
# Epoch 150/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.8633e-04 - reconstruction_loss_cont: 9.0638e-05 - reconstruction_loss_class: 7.7470e-08 - kl_loss: 0.9566 - sparse_categorical_crossentropy: 4.4072e-08 - kl_div: 0.0285
# Epoch 151/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.8360e-04 - reconstruction_loss_cont: 8.8013e-05 - reconstruction_loss_class: 4.5151e-08 - kl_loss: 0.9560 - sparse_categorical_crossentropy: 3.8930e-08 - kl_div: 0.0283
# Epoch 152/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0016 - reconstruction_loss_cont: 3.9356e-04 - reconstruction_loss_class: 0.0021 - kl_loss: 2.9674 - sparse_categorical_crossentropy: 0.0010 - kl_div: 0.0283
# Epoch 153/300
# 890/890 [==============================] - 2s 3ms/step - loss: 0.0013 - reconstruction_loss_cont: 8.6846e-04 - reconstruction_loss_class: 7.8920e-06 - kl_loss: 3.3157 - sparse_categorical_crossentropy: 1.9206e-05 - kl_div: 0.0285
# Epoch 154/300
# 890/890 [==============================] - 2s 3ms/step - loss: 7.9065e-04 - reconstruction_loss_cont: 5.8513e-04 - reconstruction_loss_class: 1.4756e-06 - kl_loss: 1.8100 - sparse_categorical_crossentropy: 7.9704e-07 - kl_div: 0.0285
# Epoch 155/300
# 890/890 [==============================] - 2s 2ms/step - loss: 5.7970e-04 - reconstruction_loss_cont: 4.4189e-04 - reconstruction_loss_class: 1.0241e-06 - kl_loss: 1.2989 - sparse_categorical_crossentropy: 1.1597e-06 - kl_div: 0.0285
# Epoch 156/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.5334e-04 - reconstruction_loss_cont: 3.3359e-04 - reconstruction_loss_class: 1.6741e-06 - kl_loss: 1.1900 - sparse_categorical_crossentropy: 1.1960e-06 - kl_div: 0.0284
# Epoch 157/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.6968e-04 - reconstruction_loss_cont: 2.5248e-04 - reconstruction_loss_class: 1.8522e-07 - kl_loss: 1.1611 - sparse_categorical_crossentropy: 1.5057e-07 - kl_div: 0.0283
# Epoch 158/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.4143e-04 - reconstruction_loss_cont: 2.2825e-04 - reconstruction_loss_class: 3.6225e-07 - kl_loss: 1.1187 - sparse_categorical_crossentropy: 3.1109e-07 - kl_div: 0.0282
# Epoch 159/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.2807e-04 - reconstruction_loss_cont: 2.1848e-04 - reconstruction_loss_class: 4.1364e-07 - kl_loss: 1.0832 - sparse_categorical_crossentropy: 3.5804e-07 - kl_div: 0.0281
# Epoch 160/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.0397e-04 - reconstruction_loss_cont: 1.9776e-04 - reconstruction_loss_class: 2.6526e-07 - kl_loss: 1.0522 - sparse_categorical_crossentropy: 2.8395e-07 - kl_div: 0.0280
# Epoch 161/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9153e-04 - reconstruction_loss_cont: 1.8742e-04 - reconstruction_loss_class: 3.0141e-07 - kl_loss: 1.0310 - sparse_categorical_crossentropy: 3.3063e-07 - kl_div: 0.0279
# Epoch 162/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6904e-04 - reconstruction_loss_cont: 1.6721e-04 - reconstruction_loss_class: 2.8467e-07 - kl_loss: 1.0142 - sparse_categorical_crossentropy: 2.3727e-07 - kl_div: 0.0278
# Epoch 163/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.5898e-04 - reconstruction_loss_cont: 1.5754e-04 - reconstruction_loss_class: 2.2825e-07 - kl_loss: 1.0095 - sparse_categorical_crossentropy: 2.1415e-07 - kl_div: 0.0277
# Epoch 164/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4407e-04 - reconstruction_loss_cont: 1.4338e-04 - reconstruction_loss_class: 2.1513e-07 - kl_loss: 1.0046 - sparse_categorical_crossentropy: 1.9931e-07 - kl_div: 0.0276
# Epoch 165/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.3102e-04 - reconstruction_loss_cont: 1.3056e-04 - reconstruction_loss_class: 2.0508e-07 - kl_loss: 1.0020 - sparse_categorical_crossentropy: 1.9005e-07 - kl_div: 0.0275
# Epoch 166/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2209e-04 - reconstruction_loss_cont: 1.2229e-04 - reconstruction_loss_class: 2.1530e-07 - kl_loss: 0.9962 - sparse_categorical_crossentropy: 2.1104e-07 - kl_div: 0.0274
# Epoch 167/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.1539e-04 - reconstruction_loss_cont: 1.1619e-04 - reconstruction_loss_class: 1.5194e-07 - kl_loss: 0.9874 - sparse_categorical_crossentropy: 1.3394e-07 - kl_div: 0.0273
# Epoch 168/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1722e-04 - reconstruction_loss_cont: 1.1801e-04 - reconstruction_loss_class: 4.5762e-07 - kl_loss: 0.9861 - sparse_categorical_crossentropy: 4.5068e-07 - kl_div: 0.0272
# Epoch 169/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0483e-04 - reconstruction_loss_cont: 1.0731e-04 - reconstruction_loss_class: 9.9910e-08 - kl_loss: 0.9710 - sparse_categorical_crossentropy: 1.1107e-07 - kl_div: 0.0271
# Epoch 170/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0488e-04 - reconstruction_loss_cont: 1.0827e-04 - reconstruction_loss_class: 1.1291e-07 - kl_loss: 0.9646 - sparse_categorical_crossentropy: 1.1172e-07 - kl_div: 0.0270
# Epoch 171/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9963e-04 - reconstruction_loss_cont: 1.0360e-04 - reconstruction_loss_class: 3.0320e-07 - kl_loss: 0.9593 - sparse_categorical_crossentropy: 1.1730e-07 - kl_div: 0.0269
# Epoch 172/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9985e-04 - reconstruction_loss_cont: 1.0383e-04 - reconstruction_loss_class: 1.1864e-07 - kl_loss: 0.9558 - sparse_categorical_crossentropy: 1.1632e-07 - kl_div: 0.0268
# Epoch 173/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8966e-04 - reconstruction_loss_cont: 9.4412e-05 - reconstruction_loss_class: 1.6346e-07 - kl_loss: 0.9503 - sparse_categorical_crossentropy: 1.3708e-07 - kl_div: 0.0267
# Epoch 174/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8823e-04 - reconstruction_loss_cont: 9.2944e-05 - reconstruction_loss_class: 1.1406e-07 - kl_loss: 0.9508 - sparse_categorical_crossentropy: 1.0374e-07 - kl_div: 0.0266
# Epoch 175/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8849e-04 - reconstruction_loss_cont: 9.3571e-05 - reconstruction_loss_class: 9.6976e-08 - kl_loss: 0.9459 - sparse_categorical_crossentropy: 1.1425e-07 - kl_div: 0.0265
# Epoch 176/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8592e-04 - reconstruction_loss_cont: 9.1032e-05 - reconstruction_loss_class: 1.4984e-07 - kl_loss: 0.9460 - sparse_categorical_crossentropy: 2.0640e-07 - kl_div: 0.0264
# Epoch 177/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.8071e-04 - reconstruction_loss_cont: 8.6435e-05 - reconstruction_loss_class: 1.0407e-07 - kl_loss: 0.9424 - sparse_categorical_crossentropy: 8.6810e-08 - kl_div: 0.0262
# Epoch 178/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8872e-04 - reconstruction_loss_cont: 9.3517e-05 - reconstruction_loss_class: 6.1399e-07 - kl_loss: 0.9475 - sparse_categorical_crossentropy: 6.4023e-07 - kl_div: 0.0261
# Epoch 179/300
# 890/890 [==============================] - 2s 3ms/step - loss: 1.7637e-04 - reconstruction_loss_cont: 8.2082e-05 - reconstruction_loss_class: 7.2232e-08 - kl_loss: 0.9407 - sparse_categorical_crossentropy: 6.0747e-08 - kl_div: 0.0260
# Epoch 180/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7258e-04 - reconstruction_loss_cont: 7.8519e-05 - reconstruction_loss_class: 9.8311e-08 - kl_loss: 0.9398 - sparse_categorical_crossentropy: 1.0559e-07 - kl_div: 0.0259
# Epoch 181/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7606e-04 - reconstruction_loss_cont: 8.2124e-05 - reconstruction_loss_class: 1.0841e-07 - kl_loss: 0.9371 - sparse_categorical_crossentropy: 9.1336e-08 - kl_div: 0.0258
# Epoch 182/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0027 - reconstruction_loss_cont: 6.8214e-04 - reconstruction_loss_class: 0.0024 - kl_loss: 2.2846 - sparse_categorical_crossentropy: 0.0018 - kl_div: 0.0258
# Epoch 183/300
# 890/890 [==============================] - 2s 3ms/step - loss: 7.9517e-04 - reconstruction_loss_cont: 6.3588e-04 - reconstruction_loss_class: 2.5702e-06 - kl_loss: 1.4745 - sparse_categorical_crossentropy: 3.6910e-06 - kl_div: 0.0259
# Epoch 184/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.8960e-04 - reconstruction_loss_cont: 3.5181e-04 - reconstruction_loss_class: 1.4159e-06 - kl_loss: 1.3551 - sparse_categorical_crossentropy: 1.2138e-06 - kl_div: 0.0259
# Epoch 185/300
# 890/890 [==============================] - 2s 3ms/step - loss: 4.2150e-04 - reconstruction_loss_cont: 2.9236e-04 - reconstruction_loss_class: 6.8675e-07 - kl_loss: 1.2645 - sparse_categorical_crossentropy: 5.9545e-07 - kl_div: 0.0258
# Epoch 186/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.7507e-04 - reconstruction_loss_cont: 2.5244e-04 - reconstruction_loss_class: 4.7896e-07 - kl_loss: 1.2117 - sparse_categorical_crossentropy: 4.9584e-07 - kl_div: 0.0258
# Epoch 187/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.2971e-04 - reconstruction_loss_cont: 2.1085e-04 - reconstruction_loss_class: 3.6021e-07 - kl_loss: 1.1747 - sparse_categorical_crossentropy: 3.7518e-07 - kl_div: 0.0257
# Epoch 188/300
# 890/890 [==============================] - 2s 3ms/step - loss: 3.0036e-04 - reconstruction_loss_cont: 1.8559e-04 - reconstruction_loss_class: 2.9658e-07 - kl_loss: 1.1334 - sparse_categorical_crossentropy: 4.0126e-07 - kl_div: 0.0256
# Epoch 189/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.8053e-04 - reconstruction_loss_cont: 1.6960e-04 - reconstruction_loss_class: 2.8772e-07 - kl_loss: 1.0965 - sparse_categorical_crossentropy: 3.0572e-07 - kl_div: 0.0256
# Epoch 190/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7268e-04 - reconstruction_loss_cont: 1.6224e-04 - reconstruction_loss_class: 5.2195e-07 - kl_loss: 1.0906 - sparse_categorical_crossentropy: 8.8146e-07 - kl_div: 0.0255
# Epoch 191/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.5354e-04 - reconstruction_loss_cont: 1.4676e-04 - reconstruction_loss_class: 1.9157e-07 - kl_loss: 1.0602 - sparse_categorical_crossentropy: 1.7523e-07 - kl_div: 0.0254
# Epoch 192/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4555e-04 - reconstruction_loss_cont: 1.4049e-04 - reconstruction_loss_class: 1.9224e-07 - kl_loss: 1.0445 - sparse_categorical_crossentropy: 1.7174e-07 - kl_div: 0.0253
# Epoch 193/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.3543e-04 - reconstruction_loss_cont: 1.3182e-04 - reconstruction_loss_class: 1.8764e-07 - kl_loss: 1.0281 - sparse_categorical_crossentropy: 1.6171e-07 - kl_div: 0.0253
# Epoch 194/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2453e-04 - reconstruction_loss_cont: 1.2234e-04 - reconstruction_loss_class: 1.9570e-07 - kl_loss: 1.0149 - sparse_categorical_crossentropy: 2.0298e-07 - kl_div: 0.0252
# Epoch 195/300
# ...
# Epoch 237/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9201e-04 - reconstruction_loss_cont: 9.9904e-05 - reconstruction_loss_class: 1.8690e-07 - kl_loss: 0.9182 - sparse_categorical_crossentropy: 1.5818e-07 - kl_div: 0.0227
# Epoch 238/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8767e-04 - reconstruction_loss_cont: 9.5987e-05 - reconstruction_loss_class: 3.5434e-07 - kl_loss: 0.9159 - sparse_categorical_crossentropy: 2.7583e-07 - kl_div: 0.0227
# Epoch 239/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8758e-04 - reconstruction_loss_cont: 9.6264e-05 - reconstruction_loss_class: 1.9259e-07 - kl_loss: 0.9112 - sparse_categorical_crossentropy: 1.9219e-07 - kl_div: 0.0226
# Epoch 240/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8234e-04 - reconstruction_loss_cont: 9.1299e-05 - reconstruction_loss_class: 1.4817e-07 - kl_loss: 0.9083 - sparse_categorical_crossentropy: 1.4693e-07 - kl_div: 0.0226
# Epoch 241/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8712e-04 - reconstruction_loss_cont: 9.6288e-05 - reconstruction_loss_class: 1.8468e-07 - kl_loss: 0.9066 - sparse_categorical_crossentropy: 1.7904e-07 - kl_div: 0.0225
# Epoch 242/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7743e-04 - reconstruction_loss_cont: 8.6652e-05 - reconstruction_loss_class: 1.5918e-07 - kl_loss: 0.9050 - sparse_categorical_crossentropy: 1.5062e-07 - kl_div: 0.0224
# Epoch 243/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7425e-04 - reconstruction_loss_cont: 8.3559e-05 - reconstruction_loss_class: 1.0853e-07 - kl_loss: 0.9053 - sparse_categorical_crossentropy: 1.0170e-07 - kl_div: 0.0224
# Epoch 244/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7511e-04 - reconstruction_loss_cont: 8.4911e-05 - reconstruction_loss_class: 1.2116e-07 - kl_loss: 0.8999 - sparse_categorical_crossentropy: 1.1220e-07 - kl_div: 0.0223
# Epoch 245/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7275e-04 - reconstruction_loss_cont: 8.2583e-05 - reconstruction_loss_class: 1.1871e-07 - kl_loss: 0.9002 - sparse_categorical_crossentropy: 1.1062e-07 - kl_div: 0.0222
# Epoch 246/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7079e-04 - reconstruction_loss_cont: 8.0840e-05 - reconstruction_loss_class: 1.4700e-07 - kl_loss: 0.8999 - sparse_categorical_crossentropy: 1.0747e-07 - kl_div: 0.0222
# Epoch 247/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7172e-04 - reconstruction_loss_cont: 8.1595e-05 - reconstruction_loss_class: 1.2284e-07 - kl_loss: 0.8990 - sparse_categorical_crossentropy: 1.1163e-07 - kl_div: 0.0221
# Epoch 248/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7767e-04 - reconstruction_loss_cont: 8.7482e-05 - reconstruction_loss_class: 1.7535e-07 - kl_loss: 0.8990 - sparse_categorical_crossentropy: 1.8461e-07 - kl_div: 0.0221
# Epoch 249/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.6798e-04 - reconstruction_loss_cont: 7.8125e-05 - reconstruction_loss_class: 8.5128e-08 - kl_loss: 0.8979 - sparse_categorical_crossentropy: 7.6882e-08 - kl_div: 0.0220
# Epoch 250/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0024 - reconstruction_loss_cont: 5.4123e-04 - reconstruction_loss_class: 0.0021 - kl_loss: 1.6586 - sparse_categorical_crossentropy: 0.0018 - kl_div: 0.0220
# Epoch 251/300
# 890/890 [==============================] - 2s 2ms/step - loss: 5.3881e-04 - reconstruction_loss_cont: 3.9610e-04 - reconstruction_loss_class: 2.2523e-07 - kl_loss: 1.3419 - sparse_categorical_crossentropy: 2.7578e-07 - kl_div: 0.0220
# Epoch 252/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.2955e-04 - reconstruction_loss_cont: 2.1075e-04 - reconstruction_loss_class: 2.5369e-07 - kl_loss: 1.1550 - sparse_categorical_crossentropy: 2.2847e-07 - kl_div: 0.0220
# Epoch 253/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7265e-04 - reconstruction_loss_cont: 1.6391e-04 - reconstruction_loss_class: 1.7423e-07 - kl_loss: 1.0737 - sparse_categorical_crossentropy: 1.5996e-07 - kl_div: 0.0220
# Epoch 254/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4741e-04 - reconstruction_loss_cont: 1.4289e-04 - reconstruction_loss_class: 9.7493e-08 - kl_loss: 1.0309 - sparse_categorical_crossentropy: 9.4930e-08 - kl_div: 0.0219
# Epoch 255/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2714e-04 - reconstruction_loss_cont: 1.2624e-04 - reconstruction_loss_class: 1.4605e-07 - kl_loss: 0.9998 - sparse_categorical_crossentropy: 2.5979e-07 - kl_div: 0.0219
# Epoch 256/300
# 890/890 [==============================] - 2s 3ms/step - loss: 2.1530e-04 - reconstruction_loss_cont: 1.1714e-04 - reconstruction_loss_class: 1.2918e-07 - kl_loss: 0.9747 - sparse_categorical_crossentropy: 1.8890e-07 - kl_div: 0.0218
# Epoch 257/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1332e-04 - reconstruction_loss_cont: 1.1703e-04 - reconstruction_loss_class: 2.0922e-07 - kl_loss: 0.9550 - sparse_categorical_crossentropy: 3.6507e-07 - kl_div: 0.0218
# Epoch 258/300
# 890/890 [==============================] - 2s 2ms/step - loss: 9.6221e-04 - reconstruction_loss_cont: 2.4434e-04 - reconstruction_loss_class: 0.0022 - kl_loss: 1.7552 - sparse_categorical_crossentropy: 6.0661e-04 - kl_div: 0.0218
# Epoch 259/300
# 890/890 [==============================] - 2s 2ms/step - loss: 9.6025e-04 - reconstruction_loss_cont: 7.4807e-04 - reconstruction_loss_class: 1.3691e-06 - kl_loss: 1.8924 - sparse_categorical_crossentropy: 1.5665e-06 - kl_div: 0.0219
# Epoch 260/300
# 890/890 [==============================] - 2s 2ms/step - loss: 5.2169e-04 - reconstruction_loss_cont: 3.6992e-04 - reconstruction_loss_class: 6.2100e-07 - kl_loss: 1.4711 - sparse_categorical_crossentropy: 8.3987e-07 - kl_div: 0.0219
# Epoch 261/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.6799e-04 - reconstruction_loss_cont: 2.2863e-04 - reconstruction_loss_class: 6.4870e-07 - kl_loss: 1.3607 - sparse_categorical_crossentropy: 7.5976e-07 - kl_div: 0.0219
# Epoch 262/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.3420e-04 - reconstruction_loss_cont: 2.0512e-04 - reconstruction_loss_class: 2.6445e-07 - kl_loss: 1.2627 - sparse_categorical_crossentropy: 2.9114e-07 - kl_div: 0.0218
# Epoch 263/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.0910e-04 - reconstruction_loss_cont: 1.8875e-04 - reconstruction_loss_class: 4.2544e-07 - kl_loss: 1.1860 - sparse_categorical_crossentropy: 2.8138e-07 - kl_div: 0.0218
# Epoch 264/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.9050e-04 - reconstruction_loss_cont: 1.7618e-04 - reconstruction_loss_class: 1.3317e-07 - kl_loss: 1.1281 - sparse_categorical_crossentropy: 1.2648e-07 - kl_div: 0.0218
# Epoch 265/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7789e-04 - reconstruction_loss_cont: 1.6804e-04 - reconstruction_loss_class: 1.7490e-07 - kl_loss: 1.0834 - sparse_categorical_crossentropy: 1.9518e-07 - kl_div: 0.0217
# Epoch 266/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6770e-04 - reconstruction_loss_cont: 1.6188e-04 - reconstruction_loss_class: 1.4955e-07 - kl_loss: 1.0479 - sparse_categorical_crossentropy: 1.1401e-07 - kl_div: 0.0217
# Epoch 267/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.6388e-04 - reconstruction_loss_cont: 1.6059e-04 - reconstruction_loss_class: 2.1323e-07 - kl_loss: 1.0221 - sparse_categorical_crossentropy: 2.6454e-07 - kl_div: 0.0217
# Epoch 268/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.4276e-04 - reconstruction_loss_cont: 1.4189e-04 - reconstruction_loss_class: 1.3019e-07 - kl_loss: 1.0026 - sparse_categorical_crossentropy: 1.1735e-07 - kl_div: 0.0216
# Epoch 269/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.2995e-04 - reconstruction_loss_cont: 1.3098e-04 - reconstruction_loss_class: 1.3170e-07 - kl_loss: 0.9850 - sparse_categorical_crossentropy: 1.8490e-07 - kl_div: 0.0216
# Epoch 270/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.7708e-04 - reconstruction_loss_cont: 1.7683e-04 - reconstruction_loss_class: 1.1207e-06 - kl_loss: 0.9773 - sparse_categorical_crossentropy: 1.8295e-06 - kl_div: 0.0215
# Epoch 271/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.1513e-04 - reconstruction_loss_cont: 1.1866e-04 - reconstruction_loss_class: 1.2824e-07 - kl_loss: 0.9590 - sparse_categorical_crossentropy: 1.4647e-07 - kl_div: 0.0215
# Epoch 272/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0701e-04 - reconstruction_loss_cont: 1.1189e-04 - reconstruction_loss_class: 6.5246e-08 - kl_loss: 0.9480 - sparse_categorical_crossentropy: 6.4987e-08 - kl_div: 0.0215
# Epoch 273/300
# 890/890 [==============================] - 2s 2ms/step - loss: 2.0050e-04 - reconstruction_loss_cont: 1.0682e-04 - reconstruction_loss_class: 7.8146e-08 - kl_loss: 0.9353 - sparse_categorical_crossentropy: 5.7190e-08 - kl_div: 0.0214
# Epoch 274/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9918e-04 - reconstruction_loss_cont: 1.0567e-04 - reconstruction_loss_class: 1.4032e-07 - kl_loss: 0.9306 - sparse_categorical_crossentropy: 2.1310e-07 - kl_div: 0.0214
# Epoch 275/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9447e-04 - reconstruction_loss_cont: 1.0189e-04 - reconstruction_loss_class: 1.3192e-07 - kl_loss: 0.9232 - sparse_categorical_crossentropy: 1.2065e-07 - kl_div: 0.0213
# Epoch 276/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9084e-04 - reconstruction_loss_cont: 9.9061e-05 - reconstruction_loss_class: 1.1208e-07 - kl_loss: 0.9170 - sparse_categorical_crossentropy: 8.9181e-08 - kl_div: 0.0213
# Epoch 277/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9295e-04 - reconstruction_loss_cont: 1.0124e-04 - reconstruction_loss_class: 6.9305e-07 - kl_loss: 0.9135 - sparse_categorical_crossentropy: 5.1476e-07 - kl_div: 0.0212
# Epoch 278/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9051e-04 - reconstruction_loss_cont: 9.9207e-05 - reconstruction_loss_class: 7.3575e-08 - kl_loss: 0.9107 - sparse_categorical_crossentropy: 7.9504e-08 - kl_div: 0.0212
# Epoch 279/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9304e-04 - reconstruction_loss_cont: 1.0116e-04 - reconstruction_loss_class: 2.3571e-06 - kl_loss: 0.9226 - sparse_categorical_crossentropy: 7.2980e-07 - kl_div: 0.0211
# Epoch 280/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.9329e-04 - reconstruction_loss_cont: 1.0064e-04 - reconstruction_loss_class: 5.1095e-07 - kl_loss: 0.9237 - sparse_categorical_crossentropy: 1.6914e-07 - kl_div: 0.0211
# Epoch 281/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8775e-04 - reconstruction_loss_cont: 9.6318e-05 - reconstruction_loss_class: 5.4929e-08 - kl_loss: 0.9119 - sparse_categorical_crossentropy: 5.0415e-08 - kl_div: 0.0211
# Epoch 282/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8197e-04 - reconstruction_loss_cont: 9.1374e-05 - reconstruction_loss_class: 5.2686e-08 - kl_loss: 0.9040 - sparse_categorical_crossentropy: 1.3367e-07 - kl_div: 0.0210
# Epoch 283/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8042e-04 - reconstruction_loss_cont: 9.0378e-05 - reconstruction_loss_class: 4.9162e-08 - kl_loss: 0.8986 - sparse_categorical_crossentropy: 4.8249e-08 - kl_div: 0.0210
# Epoch 284/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8248e-04 - reconstruction_loss_cont: 9.2531e-05 - reconstruction_loss_class: 5.9613e-08 - kl_loss: 0.8967 - sparse_categorical_crossentropy: 5.3446e-08 - kl_div: 0.0209
# Epoch 285/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7596e-04 - reconstruction_loss_cont: 8.6325e-05 - reconstruction_loss_class: 7.9601e-08 - kl_loss: 0.8950 - sparse_categorical_crossentropy: 8.6238e-08 - kl_div: 0.0209
# Epoch 286/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7871e-04 - reconstruction_loss_cont: 8.9287e-05 - reconstruction_loss_class: 1.5070e-07 - kl_loss: 0.8942 - sparse_categorical_crossentropy: 1.5157e-07 - kl_div: 0.0208
# Epoch 287/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.8191e-04 - reconstruction_loss_cont: 9.2464e-05 - reconstruction_loss_class: 6.1894e-08 - kl_loss: 0.8923 - sparse_categorical_crossentropy: 5.8511e-08 - kl_div: 0.0208
# Epoch 288/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7383e-04 - reconstruction_loss_cont: 8.4479e-05 - reconstruction_loss_class: 8.4047e-08 - kl_loss: 0.8924 - sparse_categorical_crossentropy: 1.2509e-07 - kl_div: 0.0207
# Epoch 289/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7313e-04 - reconstruction_loss_cont: 8.3762e-05 - reconstruction_loss_class: 8.7335e-08 - kl_loss: 0.8915 - sparse_categorical_crossentropy: 8.2828e-08 - kl_div: 0.0207
# Epoch 290/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7096e-04 - reconstruction_loss_cont: 8.1770e-05 - reconstruction_loss_class: 1.1695e-07 - kl_loss: 0.8902 - sparse_categorical_crossentropy: 8.4933e-08 - kl_div: 0.0207
# Epoch 291/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.7477e-04 - reconstruction_loss_cont: 8.5371e-05 - reconstruction_loss_class: 7.8243e-08 - kl_loss: 0.8912 - sparse_categorical_crossentropy: 7.4499e-08 - kl_div: 0.0206
# Epoch 292/300
# 890/890 [==============================] - 2s 2ms/step - loss: 1.6841e-04 - reconstruction_loss_cont: 7.9239e-05 - reconstruction_loss_class: 8.5362e-08 - kl_loss: 0.8906 - sparse_categorical_crossentropy: 7.8449e-08 - kl_div: 0.0206
# Epoch 293/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0051 - reconstruction_loss_cont: 0.0012 - reconstruction_loss_class: 0.0030 - kl_loss: 3.0471 - sparse_categorical_crossentropy: 0.0037 - kl_div: 0.0206
# Epoch 294/300
# 890/890 [==============================] - 2s 2ms/step - loss: 8.6712e-04 - reconstruction_loss_cont: 7.2352e-04 - reconstruction_loss_class: 3.9569e-06 - kl_loss: 1.3749 - sparse_categorical_crossentropy: 3.4065e-06 - kl_div: 0.0207
# Epoch 295/300
# 890/890 [==============================] - 2s 2ms/step - loss: 5.8611e-04 - reconstruction_loss_cont: 4.4804e-04 - reconstruction_loss_class: 1.6585e-07 - kl_loss: 1.3077 - sparse_categorical_crossentropy: 1.3504e-07 - kl_div: 0.0207
# Epoch 296/300
# 890/890 [==============================] - 2s 2ms/step - loss: 4.7335e-04 - reconstruction_loss_cont: 3.5202e-04 - reconstruction_loss_class: 4.0190e-07 - kl_loss: 1.1930 - sparse_categorical_crossentropy: 3.1647e-07 - kl_div: 0.0207
# Epoch 297/300
# 890/890 [==============================] - 2s 2ms/step - loss: 3.9591e-04 - reconstruction_loss_cont: 2.8032e-04 - reconstruction_loss_class: 6.5287e-07 - kl_loss: 1.1360 - sparse_categorical_crossentropy: 5.4222e-07 - kl_div: 0.0207
# Epoch 298/300
# 890/890 [==============================] - 2s 2ms/step - loss: 0.0065 - reconstruction_loss_cont: 0.0013 - reconstruction_loss_class: 0.0026 - kl_loss: 3.7446 - sparse_categorical_crossentropy: 0.0048 - kl_div: 0.0207
# Epoch 299/300
# 890/890 [==============================] - 3s 3ms/step - loss: 9.1807e-04 - reconstruction_loss_cont: 7.0656e-04 - reconstruction_loss_class: 1.6563e-08 - kl_loss: 1.8672 - sparse_categorical_crossentropy: 1.0171e-08 - kl_div: 0.0208
# Epoch 300/300
# 890/890 [==============================] - 2s 3ms/step - loss: 6.5392e-04 - reconstruction_loss_cont: 5.0432e-04 - reconstruction_loss_class: 7.5494e-07 - kl_loss: 1.4412 - sparse_categorical_crossentropy: 1.1446e-06 - kl_div: 0.0208

# %%
# call_for_saving = vae(train_data_array[:1])

# %%
# vae.save("../models/VAE/optimized_for_data", save_format="tf")

# %% [markdown]
# # Synth Data Creation

# %%
# synth Data from Data
generated_data_cont_from_data, generated_data_class_from_data = vae.decoder.predict(
    encoder(train_data_array)[2]
)
# Out:
# 890/890 [==============================] - 1s 1ms/step

# %% [markdown]
# Saving the synth data from data

# %%
binary_predictions_from_data = (generated_data_class_from_data >= 0.5).astype(int)
print(sum(binary_predictions_from_data))

# Create DataFrame with synthetic data
synthetic_data_from_data = pd.DataFrame(generated_data_cont_from_data, columns=train_data.columns[:-1])
# Add binary_predictions as an additional column
synthetic_data_from_data["Class"] = binary_predictions_from_data
synthetic_data_from_data.to_csv(f"../data/interim/privacy_testing/Epoch_{epoch}_synthdata_from_data_train_random_sample_for_privacy.csv", index=False)
# Out:
# [56]

# %%
# synth Data from Data random sample
latent_vectors = np.random.normal(scale=1, size=(len(train_data), latent_dim))
generated_data_cont_from_sample, generated_data_class_from_sample = vae.decoder.predict(
    latent_vectors
)
# Saving the synth data from sample
binary_predictions_from_sample = (generated_data_class_from_sample >= 0.5).astype(int)
print(sum(binary_predictions_from_sample))

# Create DataFrame with synthetic data
synthetic_data_from_sample = pd.DataFrame(
    generated_data_cont_from_sample, columns=train_data.columns[:-1]
)
# Add binary_predictions as an additional column
synthetic_data_from_sample["Class"] = binary_predictions_from_sample
synthetic_data_from_sample.to_csv(
    f"../data/interim/privacy_testing/Epoch_{epoch}_synthdata_from_sample_train_random_sample_for_privacy.csv",index=False,)
# Out:
# 890/890 [==============================] - 1s 1ms/step
# [1058]
